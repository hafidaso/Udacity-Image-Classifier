# %% [markdown]
# ## Prepare the workspace

# %%
# Before you proceed, update the PATH
import os
os.environ['PATH'] = f"{os.environ['PATH']}:/root/.local/bin"
os.environ['PATH'] = f"{os.environ['PATH']}:/opt/conda/lib/python3.6/site-packages"
# Restart the Kernel at this point.

# %%
# Check torch version and CUDA status if GPU is enabled.
import torch
print(torch.__version__)
print(torch.cuda.is_available()) # Should return True when GPU is enabled.
# Out:
# 2.0.0
# True

# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch import tensor
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
from torchvision import datasets, transforms
import torchvision.models as models
import argparse
from collections import OrderedDict
import json
import PIL
import seaborn as sns
from PIL import Image
import time

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz).

# %% [markdown]
# If you do not find the `flowers/` dataset in the current directory, **/workspace/home/aipnd-project/**, you can download it using the following commands.
#
# ```bash
# !wget 'https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz'
# !unlink flowers
# !mkdir flowers && tar -xzf flower_data.tar.gz -C flowers
# ```

# %%
# !wget 'https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz'
# !unlink flowers
# !mkdir flowers && tar -xzf flower_data.tar.gz -C flowers
# Out:
# --2023-12-29 18:32:46--  https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 16.182.33.56, 52.216.164.221, 52.217.204.216, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|16.182.33.56|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 344873452 (329M) [application/x-gzip]
# Saving to: 'flower_data.tar.gz'
#
# flower_data.tar.gz  100%[===================>] 328.90M  57.1MB/s    in 5.3s
#
# 2023-12-29 18:32:52 (61.8 MB/s) - 'flower_data.tar.gz' saved [344873452/344873452]
#
# unlink: cannot unlink 'flowers': No such file or directory

# %% [markdown]
# ## Data Description
# The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
class_sample_count = []

with open('/kaggle/input/image-clas/cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)


for k, v in cat_to_name.items():
    dir_images = '/kaggle/working/flowers/train/'+k        
    path, dirs, files = next(os.walk(dir_images))
    class_sample_count.append(len(files))
    
    
# %matplotlib inline 
# %config InlineBackend.figure_format = 'retina'


plt.hist(class_sample_count, bins=10)
plt.ylabel('Number of examples for each class')
plt.show()

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
data_transforms = { 
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                             [0.229,0.224,0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                             [0.229,0.224,0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                             [0.229,0.224,0.225])
    ])
}

# TODO: Load the datasets with ImageFolder
image_datasets = {
    'train': datasets.ImageFolder(train_dir, transform=data_transforms['train']),
    'valid': datasets.ImageFolder(valid_dir, transform=data_transforms['valid']),
    'test': datasets.ImageFolder(test_dir, transform=data_transforms['test'])
}

# TODO: Using the image datasets and the trainforms, define the dataloaders
train_loader = torch.utils.data.DataLoader(image_datasets['train'], batch_size=64, shuffle=True)
validation_loader = torch.utils.data.DataLoader(image_datasets['valid'], batch_size =64,shuffle = True)
test_loader = torch.utils.data.DataLoader(image_datasets['test'], batch_size = 64, shuffle = True)

# Size of Loaders, to be used for calculating Average Loss and Accuracy
train_Loader_size = len(train_loader)
valid_Loader_size = len(validation_loader)
test_loader_size = len(test_loader)


# Print the train, validation and test set data sizes
train_Loader_size, valid_Loader_size, test_loader_size
# Out:
# (103, 13, 13)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('/kaggle/input/image-clas/cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# ## Note for Workspace users:
# If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network

# Load pretrained vgg16 Model
#vgg16 have several advantages: It has so many weight parameters, the models are very heavy, 550 MB + of weight size, 
#Which also means long inference time
#source (https://forums.fast.ai/t/vgg-strength-and-limitations/1218)

model = models.vgg16(pretrained=True)

#When a model is loaded in PyTorch, all its parameters have their ‘requires_grad‘ field set to true by default. 
#That means each and every change to the parameter values will be stored in order to be used in the back propagation graph 
#used for training. This increases memory requirements. So,
#since most of the parameters in our pre-trained model are already trained for us, we reset the requires_grad field to false.

#to freeze part of the convolutional part of vgg16 model and train the rest
for param in model.parameters():
    param.requires_grad = False
        
#Then we replace the final layer of the vgg16 model by a small set of Sequential layers. 
#The inputs to the last fully connected layer of vgg16 is fed to a Linear layer, 
#which are then fed into ReLU (rectified linear unit) and Dropout layers.


#Used OrderedDict to preserve the order in which the keys are inserted
from collections import OrderedDict

classifier = nn.Sequential(OrderedDict([
            ('inputs', nn.Linear(25088, 120)), #hidden layer 1 sets output to 120
            ('relu1', nn.ReLU()),
            ('dropout',nn.Dropout(0.5)), #could use a different droupout probability,but 0.5 usually works well
            ('hidden_layer1', nn.Linear(120, 90)), #hidden layer 2 output to 90
            ('relu2',nn.ReLU()),
            ('hidden_layer2',nn.Linear(90,70)), #hidden layer 3 output to 70
            ('relu3',nn.ReLU()),
            ('hidden_layer3',nn.Linear(70,102)),#output size = 102
            ('output', nn.LogSoftmax(dim=1))]))# For using NLLLoss()
   
model.classifier = classifier
        
#Since we will be doing the training on a GPU, we get the model ready for GPU.

# Convert model to be used on GPU
if torch.cuda.is_available():
    model.cuda()

#define the criterion and the optimizer to be used for training.
#Negative Loss Likelihood function(NLLLoss()) as it can be used for classifying multiple classes.
#Adam is one the most popular optimizers because it can adapt the learning rate for each parameter individually.

criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:02<00:00, 261MB/s]

# %%
#Training is carried out for a fixed set of epochs, processing each image once in a single epoch.
#The training data loader loads data in batches.
#In our case, we have given a batch size of 64, which means each batch can have at most 64 images.

#with transfer learning, we need to compute gradients only for a small set of parameters 
#that belong to the few newly added layers towards the end of the model.

#Gradient computation is done using the autograd and back propagation.
#PyTorch accumulates all the gradients in the backward pass. 
# So it is essential to zero them out at the beginning of the training loop.
#This is achieved using the optimizer’s zero_grad function.

#Finally, after the gradients are computed in the backward pass, the parameters are updated using the optimizer’s step function.

#Total loss and accuracy is computed for the whole batch, 
#which is then averaged over all the batches to get the loss and accuracy values for the whole epoch.

epochs=18
for epoch in range(epochs):
    print("Epoch: {}/{}".format(epoch+1, epochs))
     
# tell the model that you are training . So effectively layers like dropout, batchnorm etc,
#which behave different on the train and test procedures know what is going on and hence can behave accordingly.
# Set to training mode    
    # Set to training mode
    model.train()
     
    # Loss and Accuracy within the epoch
    train_loss = 0.0
    train_acc = 0.0
     
    valid_loss = 0.0
    valid_acc = 0.0
 
    for i, (inputs, labels) in enumerate(train_loader):
 
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')
         
        # Clean existing gradients
        optimizer.zero_grad()
         
        # Forward pass - compute outputs on input data using the model
        outputs = model(inputs)
         
        # Compute loss
        loss = criterion(outputs, labels)
         
        # Backpropagate the gradients
        loss.backward()
         
        # Update the parameters
        optimizer.step()
         
        # Compute the total loss for the batch and add it to train_loss
        train_loss += loss.item() * inputs.size(0)
         
        # Compute the accuracy
        ret, predictions = torch.max(outputs.data, 1)
        correct_counts = predictions.eq(labels.data.view_as(predictions))
         
        # Convert correct_counts to float and then compute the mean
        acc = torch.mean(correct_counts.type(torch.FloatTensor))
         
        # Compute total accuracy in the whole batch and add to train_acc
        train_acc += acc.item() * inputs.size(0)
         
        print("Batch no: {:03d}, Loss on trainig: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))
# Out:
# Epoch: 1/18
# Batch no: 000, Loss on trainig: 4.6319, Accuracy: 0.0156
# Batch no: 001, Loss on trainig: 4.6264, Accuracy: 0.0469
# Batch no: 002, Loss on trainig: 4.6477, Accuracy: 0.0000
# Batch no: 003, Loss on trainig: 4.6589, Accuracy: 0.0156
# Batch no: 004, Loss on trainig: 4.6310, Accuracy: 0.0000
# Batch no: 005, Loss on trainig: 4.6374, Accuracy: 0.0312
# Batch no: 006, Loss on trainig: 4.6282, Accuracy: 0.0312
# Batch no: 007, Loss on trainig: 4.6030, Accuracy: 0.0938
# Batch no: 008, Loss on trainig: 4.5360, Accuracy: 0.0625
# Batch no: 009, Loss on trainig: 4.4973, Accuracy: 0.0781
# Batch no: 010, Loss on trainig: 4.5410, Accuracy: 0.0625
# Batch no: 011, Loss on trainig: 4.5733, Accuracy: 0.0156
# Batch no: 012, Loss on trainig: 4.5301, Accuracy: 0.0312
# Batch no: 013, Loss on trainig: 4.5454, Accuracy: 0.0469
# Batch no: 014, Loss on trainig: 4.5334, Accuracy: 0.0469
# Batch no: 015, Loss on trainig: 4.4405, Accuracy: 0.0312
# Batch no: 016, Loss on trainig: 4.6413, Accuracy: 0.0000
# Batch no: 017, Loss on trainig: 4.6035, Accuracy: 0.0312
# Batch no: 018, Loss on trainig: 4.5379, Accuracy: 0.0312
# Batch no: 019, Loss on trainig: 4.4909, Accuracy: 0.0312
# Batch no: 020, Loss on trainig: 4.4664, Accuracy: 0.0469
# Batch no: 021, Loss on trainig: 4.4729, Accuracy: 0.0625
# Batch no: 022, Loss on trainig: 4.5231, Accuracy: 0.0469
# Batch no: 023, Loss on trainig: 4.4998, Accuracy: 0.0625
# Batch no: 024, Loss on trainig: 4.3324, Accuracy: 0.0625
# Batch no: 025, Loss on trainig: 4.4361, Accuracy: 0.0781
# Batch no: 026, Loss on trainig: 4.5030, Accuracy: 0.0469
# Batch no: 027, Loss on trainig: 4.1878, Accuracy: 0.0625
# Batch no: 028, Loss on trainig: 4.3893, Accuracy: 0.0938
# Batch no: 029, Loss on trainig: 4.3997, Accuracy: 0.0312
# Batch no: 030, Loss on trainig: 4.4144, Accuracy: 0.0469
# Batch no: 031, Loss on trainig: 4.4619, Accuracy: 0.0781
# Batch no: 032, Loss on trainig: 4.2193, Accuracy: 0.1406
# Batch no: 033, Loss on trainig: 4.5255, Accuracy: 0.0000
# Batch no: 034, Loss on trainig: 4.2921, Accuracy: 0.0781
# Batch no: 035, Loss on trainig: 4.1480, Accuracy: 0.0625
# Batch no: 036, Loss on trainig: 4.3974, Accuracy: 0.0312
# Batch no: 037, Loss on trainig: 4.2708, Accuracy: 0.0781
# Batch no: 038, Loss on trainig: 4.3282, Accuracy: 0.0312
# Batch no: 039, Loss on trainig: 4.2462, Accuracy: 0.0938
# Batch no: 040, Loss on trainig: 4.2949, Accuracy: 0.0625
# Batch no: 041, Loss on trainig: 4.2030, Accuracy: 0.0781
# Batch no: 042, Loss on trainig: 4.3511, Accuracy: 0.0781
# Batch no: 043, Loss on trainig: 4.0150, Accuracy: 0.1094
# Batch no: 044, Loss on trainig: 4.0126, Accuracy: 0.0781
# Batch no: 045, Loss on trainig: 4.4068, Accuracy: 0.0781
# Batch no: 046, Loss on trainig: 4.1498, Accuracy: 0.1094
# Batch no: 047, Loss on trainig: 4.1403, Accuracy: 0.1406
# Batch no: 048, Loss on trainig: 3.9250, Accuracy: 0.1250
# Batch no: 049, Loss on trainig: 4.2365, Accuracy: 0.0312
# Batch no: 050, Loss on trainig: 4.0491, Accuracy: 0.0781
# Batch no: 051, Loss on trainig: 4.2850, Accuracy: 0.1094
# Batch no: 052, Loss on trainig: 4.1386, Accuracy: 0.0938
# Batch no: 053, Loss on trainig: 4.2255, Accuracy: 0.0781
# Batch no: 054, Loss on trainig: 3.9048, Accuracy: 0.1562
# Batch no: 055, Loss on trainig: 4.2026, Accuracy: 0.1094
# Batch no: 056, Loss on trainig: 4.0985, Accuracy: 0.0781
# Batch no: 057, Loss on trainig: 4.0978, Accuracy: 0.1406
# Batch no: 058, Loss on trainig: 4.2757, Accuracy: 0.0781
# Batch no: 059, Loss on trainig: 3.8685, Accuracy: 0.0938
# Batch no: 060, Loss on trainig: 3.6996, Accuracy: 0.1094
# Batch no: 061, Loss on trainig: 3.8289, Accuracy: 0.1406
# Batch no: 062, Loss on trainig: 3.9339, Accuracy: 0.0781
# Batch no: 063, Loss on trainig: 3.8154, Accuracy: 0.1406
# Batch no: 064, Loss on trainig: 3.9057, Accuracy: 0.1094
# Batch no: 065, Loss on trainig: 3.9899, Accuracy: 0.1719
# Batch no: 066, Loss on trainig: 3.8684, Accuracy: 0.1719
# Batch no: 067, Loss on trainig: 3.8902, Accuracy: 0.0938
# Batch no: 068, Loss on trainig: 3.6983, Accuracy: 0.1562
# Batch no: 069, Loss on trainig: 4.0136, Accuracy: 0.1094
# Batch no: 070, Loss on trainig: 3.8039, Accuracy: 0.1250
# Batch no: 071, Loss on trainig: 3.7305, Accuracy: 0.1875
# Batch no: 072, Loss on trainig: 3.7010, Accuracy: 0.1406
# Batch no: 073, Loss on trainig: 3.7173, Accuracy: 0.2188
# Batch no: 074, Loss on trainig: 3.7936, Accuracy: 0.1250
# Batch no: 075, Loss on trainig: 3.3429, Accuracy: 0.2500
# Batch no: 076, Loss on trainig: 3.3870, Accuracy: 0.2812
# Batch no: 077, Loss on trainig: 3.7582, Accuracy: 0.1562
# Batch no: 078, Loss on trainig: 3.5651, Accuracy: 0.1875
# Batch no: 079, Loss on trainig: 3.4832, Accuracy: 0.1875
# Batch no: 080, Loss on trainig: 3.5696, Accuracy: 0.1250
# Batch no: 081, Loss on trainig: 3.4003, Accuracy: 0.1250
# Batch no: 082, Loss on trainig: 3.5467, Accuracy: 0.1094
# Batch no: 083, Loss on trainig: 3.5562, Accuracy: 0.2031
# Batch no: 084, Loss on trainig: 3.7773, Accuracy: 0.1719
# Batch no: 085, Loss on trainig: 3.2646, Accuracy: 0.1719
# Batch no: 086, Loss on trainig: 3.3974, Accuracy: 0.2188
# Batch no: 087, Loss on trainig: 3.7697, Accuracy: 0.1719
# Batch no: 088, Loss on trainig: 3.3933, Accuracy: 0.1875
# Batch no: 089, Loss on trainig: 3.5645, Accuracy: 0.1406
# Batch no: 090, Loss on trainig: 3.4827, Accuracy: 0.1719
# Batch no: 091, Loss on trainig: 3.2760, Accuracy: 0.2812
# Batch no: 092, Loss on trainig: 3.4479, Accuracy: 0.2656
# Batch no: 093, Loss on trainig: 3.2457, Accuracy: 0.2344
# Batch no: 094, Loss on trainig: 3.4398, Accuracy: 0.1875
# Batch no: 095, Loss on trainig: 3.1634, Accuracy: 0.2344
# Batch no: 096, Loss on trainig: 3.4038, Accuracy: 0.1719
# Batch no: 097, Loss on trainig: 3.5623, Accuracy: 0.2656
# Batch no: 098, Loss on trainig: 3.3331, Accuracy: 0.2500
# Batch no: 099, Loss on trainig: 3.5403, Accuracy: 0.1406
# Batch no: 100, Loss on trainig: 3.3958, Accuracy: 0.2344
# Batch no: 101, Loss on trainig: 3.3682, Accuracy: 0.2031
# Batch no: 102, Loss on trainig: 3.5449, Accuracy: 0.1667
# Epoch: 2/18
# Batch no: 000, Loss on trainig: 3.1199, Accuracy: 0.2188
# Batch no: 001, Loss on trainig: 3.2710, Accuracy: 0.1875
# Batch no: 002, Loss on trainig: 3.3539, Accuracy: 0.2344
# Batch no: 003, Loss on trainig: 3.2707, Accuracy: 0.2188
# Batch no: 004, Loss on trainig: 3.2353, Accuracy: 0.2188
# Batch no: 005, Loss on trainig: 2.9076, Accuracy: 0.2812
# Batch no: 006, Loss on trainig: 3.0725, Accuracy: 0.2500
# Batch no: 007, Loss on trainig: 3.7591, Accuracy: 0.1250
# Batch no: 008, Loss on trainig: 3.0231, Accuracy: 0.2812
# Batch no: 009, Loss on trainig: 3.2528, Accuracy: 0.2656
# Batch no: 010, Loss on trainig: 3.4770, Accuracy: 0.2188
# Batch no: 011, Loss on trainig: 2.9002, Accuracy: 0.2812
# Batch no: 012, Loss on trainig: 3.4641, Accuracy: 0.1562
# Batch no: 013, Loss on trainig: 2.6797, Accuracy: 0.3281
# Batch no: 014, Loss on trainig: 2.8848, Accuracy: 0.2812
# Batch no: 015, Loss on trainig: 3.1069, Accuracy: 0.2500
# Batch no: 016, Loss on trainig: 2.7575, Accuracy: 0.2812
# Batch no: 017, Loss on trainig: 2.9324, Accuracy: 0.2500
# Batch no: 018, Loss on trainig: 3.1742, Accuracy: 0.2812
# Batch no: 019, Loss on trainig: 3.0347, Accuracy: 0.3281
# Batch no: 020, Loss on trainig: 3.0605, Accuracy: 0.2031
# Batch no: 021, Loss on trainig: 3.1352, Accuracy: 0.2188
# Batch no: 022, Loss on trainig: 3.1093, Accuracy: 0.2344
# Batch no: 023, Loss on trainig: 3.0962, Accuracy: 0.3125
# Batch no: 024, Loss on trainig: 3.1140, Accuracy: 0.2031
# Batch no: 025, Loss on trainig: 2.8691, Accuracy: 0.3125
# Batch no: 026, Loss on trainig: 3.1900, Accuracy: 0.2031
# Batch no: 027, Loss on trainig: 2.8489, Accuracy: 0.2812
# Batch no: 028, Loss on trainig: 2.7482, Accuracy: 0.3438
# Batch no: 029, Loss on trainig: 3.0358, Accuracy: 0.2188
# Batch no: 030, Loss on trainig: 3.1075, Accuracy: 0.1719
# Batch no: 031, Loss on trainig: 2.7331, Accuracy: 0.2969
# Batch no: 032, Loss on trainig: 3.1742, Accuracy: 0.2188
# Batch no: 033, Loss on trainig: 2.9998, Accuracy: 0.2500
# Batch no: 034, Loss on trainig: 2.7677, Accuracy: 0.3125
# Batch no: 035, Loss on trainig: 2.5183, Accuracy: 0.3438
# Batch no: 036, Loss on trainig: 2.9863, Accuracy: 0.2500
# Batch no: 037, Loss on trainig: 2.9190, Accuracy: 0.2656
# Batch no: 038, Loss on trainig: 3.2500, Accuracy: 0.2500
# Batch no: 039, Loss on trainig: 3.0914, Accuracy: 0.2031
# Batch no: 040, Loss on trainig: 2.8500, Accuracy: 0.2656
# Batch no: 041, Loss on trainig: 3.1753, Accuracy: 0.1875
# Batch no: 042, Loss on trainig: 3.0711, Accuracy: 0.1406
# Batch no: 043, Loss on trainig: 2.7650, Accuracy: 0.1875
# Batch no: 044, Loss on trainig: 2.5311, Accuracy: 0.3594
# Batch no: 045, Loss on trainig: 3.0495, Accuracy: 0.2344
# Batch no: 046, Loss on trainig: 2.6457, Accuracy: 0.2969
# Batch no: 047, Loss on trainig: 2.8785, Accuracy: 0.2656
# Batch no: 048, Loss on trainig: 3.1158, Accuracy: 0.2031
# Batch no: 049, Loss on trainig: 3.0098, Accuracy: 0.2500
# Batch no: 050, Loss on trainig: 2.2977, Accuracy: 0.3750
# Batch no: 051, Loss on trainig: 2.4902, Accuracy: 0.2969
# Batch no: 052, Loss on trainig: 2.4861, Accuracy: 0.3281
# Batch no: 053, Loss on trainig: 2.7580, Accuracy: 0.2656
# Batch no: 054, Loss on trainig: 2.5552, Accuracy: 0.3438
# Batch no: 055, Loss on trainig: 2.5797, Accuracy: 0.4062
# Batch no: 056, Loss on trainig: 2.8403, Accuracy: 0.2969
# Batch no: 057, Loss on trainig: 2.5495, Accuracy: 0.3594
# Batch no: 058, Loss on trainig: 2.5777, Accuracy: 0.3281
# Batch no: 059, Loss on trainig: 2.5061, Accuracy: 0.3594
# Batch no: 060, Loss on trainig: 2.2751, Accuracy: 0.3906
# Batch no: 061, Loss on trainig: 2.7888, Accuracy: 0.2969
# Batch no: 062, Loss on trainig: 2.5295, Accuracy: 0.2969
# Batch no: 063, Loss on trainig: 2.4234, Accuracy: 0.3594
# Batch no: 064, Loss on trainig: 2.7862, Accuracy: 0.2656
# Batch no: 065, Loss on trainig: 2.8543, Accuracy: 0.3125
# Batch no: 066, Loss on trainig: 2.7054, Accuracy: 0.2656
# Batch no: 067, Loss on trainig: 2.4035, Accuracy: 0.3281
# Batch no: 068, Loss on trainig: 2.5483, Accuracy: 0.3750
# Batch no: 069, Loss on trainig: 2.7204, Accuracy: 0.2656
# Batch no: 070, Loss on trainig: 2.7194, Accuracy: 0.3125
# Batch no: 071, Loss on trainig: 2.5904, Accuracy: 0.3281
# Batch no: 072, Loss on trainig: 2.3748, Accuracy: 0.3906
# Batch no: 073, Loss on trainig: 2.7594, Accuracy: 0.2812
# Batch no: 074, Loss on trainig: 2.4233, Accuracy: 0.3594
# Batch no: 075, Loss on trainig: 2.7507, Accuracy: 0.2344
# Batch no: 076, Loss on trainig: 2.6612, Accuracy: 0.2500
# Batch no: 077, Loss on trainig: 2.6704, Accuracy: 0.3281
# Batch no: 078, Loss on trainig: 2.7262, Accuracy: 0.2812
# Batch no: 079, Loss on trainig: 2.6074, Accuracy: 0.3594
# Batch no: 080, Loss on trainig: 2.4577, Accuracy: 0.2969
# Batch no: 081, Loss on trainig: 2.7020, Accuracy: 0.3750
# Batch no: 082, Loss on trainig: 2.3097, Accuracy: 0.4531
# Batch no: 083, Loss on trainig: 2.7560, Accuracy: 0.2031
# Batch no: 084, Loss on trainig: 2.6027, Accuracy: 0.3125
# Batch no: 085, Loss on trainig: 2.8517, Accuracy: 0.3281
# Batch no: 086, Loss on trainig: 2.2075, Accuracy: 0.4062
# Batch no: 087, Loss on trainig: 2.5189, Accuracy: 0.3906
# Batch no: 088, Loss on trainig: 2.2699, Accuracy: 0.4531
# Batch no: 089, Loss on trainig: 2.7091, Accuracy: 0.2812
# Batch no: 090, Loss on trainig: 2.4867, Accuracy: 0.2656
# Batch no: 091, Loss on trainig: 2.7456, Accuracy: 0.3281
# Batch no: 092, Loss on trainig: 2.6071, Accuracy: 0.3906
# Batch no: 093, Loss on trainig: 2.3365, Accuracy: 0.3750
# Batch no: 094, Loss on trainig: 2.7025, Accuracy: 0.2969
# Batch no: 095, Loss on trainig: 2.6362, Accuracy: 0.3438
# Batch no: 096, Loss on trainig: 2.5079, Accuracy: 0.3750
# Batch no: 097, Loss on trainig: 2.6131, Accuracy: 0.3125
# Batch no: 098, Loss on trainig: 2.3188, Accuracy: 0.3594
# Batch no: 099, Loss on trainig: 2.5601, Accuracy: 0.2969
# Batch no: 100, Loss on trainig: 2.2068, Accuracy: 0.3750
# Batch no: 101, Loss on trainig: 2.3049, Accuracy: 0.4219
# Batch no: 102, Loss on trainig: 1.8753, Accuracy: 0.6250
# Epoch: 3/18
# Batch no: 000, Loss on trainig: 2.3800, Accuracy: 0.2500
# Batch no: 001, Loss on trainig: 2.0502, Accuracy: 0.4062
# Batch no: 002, Loss on trainig: 2.3597, Accuracy: 0.4531
# Batch no: 003, Loss on trainig: 2.0893, Accuracy: 0.4375
# Batch no: 004, Loss on trainig: 2.2256, Accuracy: 0.4844
# Batch no: 005, Loss on trainig: 2.2681, Accuracy: 0.4219
# Batch no: 006, Loss on trainig: 2.0130, Accuracy: 0.5000
# Batch no: 007, Loss on trainig: 2.5435, Accuracy: 0.2500
# Batch no: 008, Loss on trainig: 2.1735, Accuracy: 0.5156
# Batch no: 009, Loss on trainig: 2.2629, Accuracy: 0.4375
# Batch no: 010, Loss on trainig: 2.6601, Accuracy: 0.3438
# Batch no: 011, Loss on trainig: 2.5001, Accuracy: 0.3438
# Batch no: 012, Loss on trainig: 2.3299, Accuracy: 0.3750
# Batch no: 013, Loss on trainig: 2.7199, Accuracy: 0.3125
# Batch no: 014, Loss on trainig: 2.2803, Accuracy: 0.3906
# Batch no: 015, Loss on trainig: 2.1562, Accuracy: 0.4062
# Batch no: 016, Loss on trainig: 2.5071, Accuracy: 0.2969
# Batch no: 017, Loss on trainig: 2.0735, Accuracy: 0.4531
# Batch no: 018, Loss on trainig: 2.0596, Accuracy: 0.4531
# Batch no: 019, Loss on trainig: 2.4408, Accuracy: 0.2969
# Batch no: 020, Loss on trainig: 2.5156, Accuracy: 0.3438
# Batch no: 021, Loss on trainig: 2.2557, Accuracy: 0.4375
# Batch no: 022, Loss on trainig: 2.3256, Accuracy: 0.4062
# Batch no: 023, Loss on trainig: 2.3593, Accuracy: 0.3125
# Batch no: 024, Loss on trainig: 2.2417, Accuracy: 0.3594
# Batch no: 025, Loss on trainig: 2.3845, Accuracy: 0.3750
# Batch no: 026, Loss on trainig: 2.2484, Accuracy: 0.4062
# Batch no: 027, Loss on trainig: 2.8434, Accuracy: 0.3594
# Batch no: 028, Loss on trainig: 2.4721, Accuracy: 0.4375
# Batch no: 029, Loss on trainig: 2.1550, Accuracy: 0.3750
# Batch no: 030, Loss on trainig: 2.2446, Accuracy: 0.3906
# Batch no: 031, Loss on trainig: 2.3949, Accuracy: 0.3438
# Batch no: 032, Loss on trainig: 2.4763, Accuracy: 0.3594
# Batch no: 033, Loss on trainig: 2.0931, Accuracy: 0.4844
# Batch no: 034, Loss on trainig: 2.5560, Accuracy: 0.2812
# Batch no: 035, Loss on trainig: 2.2568, Accuracy: 0.4062
# Batch no: 036, Loss on trainig: 2.3787, Accuracy: 0.3594
# Batch no: 037, Loss on trainig: 2.3915, Accuracy: 0.4062
# Batch no: 038, Loss on trainig: 2.4722, Accuracy: 0.3281
# Batch no: 039, Loss on trainig: 2.1353, Accuracy: 0.4062
# Batch no: 040, Loss on trainig: 1.9818, Accuracy: 0.4375
# Batch no: 041, Loss on trainig: 2.4763, Accuracy: 0.3281
# Batch no: 042, Loss on trainig: 2.4528, Accuracy: 0.3281
# Batch no: 043, Loss on trainig: 2.0467, Accuracy: 0.4688
# Batch no: 044, Loss on trainig: 2.5335, Accuracy: 0.3438
# Batch no: 045, Loss on trainig: 2.4098, Accuracy: 0.4219
# Batch no: 046, Loss on trainig: 2.0971, Accuracy: 0.4844
# Batch no: 047, Loss on trainig: 2.3146, Accuracy: 0.4062
# Batch no: 048, Loss on trainig: 2.4589, Accuracy: 0.3281
# Batch no: 049, Loss on trainig: 2.4390, Accuracy: 0.4219
# Batch no: 050, Loss on trainig: 2.3348, Accuracy: 0.3750
# Batch no: 051, Loss on trainig: 2.5197, Accuracy: 0.3594
# Batch no: 052, Loss on trainig: 2.1465, Accuracy: 0.4062
# Batch no: 053, Loss on trainig: 1.9839, Accuracy: 0.4219
# Batch no: 054, Loss on trainig: 2.0955, Accuracy: 0.4219
# Batch no: 055, Loss on trainig: 2.4337, Accuracy: 0.3594
# Batch no: 056, Loss on trainig: 2.5711, Accuracy: 0.3281
# Batch no: 057, Loss on trainig: 2.3933, Accuracy: 0.3281
# Batch no: 058, Loss on trainig: 1.7253, Accuracy: 0.5781
# Batch no: 059, Loss on trainig: 1.9790, Accuracy: 0.4531
# Batch no: 060, Loss on trainig: 2.1137, Accuracy: 0.4219
# Batch no: 061, Loss on trainig: 2.5281, Accuracy: 0.3281
# Batch no: 062, Loss on trainig: 1.7998, Accuracy: 0.5000
# Batch no: 063, Loss on trainig: 2.3260, Accuracy: 0.3906
# Batch no: 064, Loss on trainig: 2.1999, Accuracy: 0.3594
# Batch no: 065, Loss on trainig: 2.2190, Accuracy: 0.4062
# Batch no: 066, Loss on trainig: 2.1476, Accuracy: 0.4219
# Batch no: 067, Loss on trainig: 2.6197, Accuracy: 0.3438
# Batch no: 068, Loss on trainig: 1.9488, Accuracy: 0.4219
# Batch no: 069, Loss on trainig: 1.9911, Accuracy: 0.5000
# Batch no: 070, Loss on trainig: 2.1882, Accuracy: 0.4219
# Batch no: 071, Loss on trainig: 1.8851, Accuracy: 0.4219
# Batch no: 072, Loss on trainig: 2.0806, Accuracy: 0.5156
# Batch no: 073, Loss on trainig: 2.2032, Accuracy: 0.4062
# Batch no: 074, Loss on trainig: 1.7515, Accuracy: 0.5625
# Batch no: 075, Loss on trainig: 2.0205, Accuracy: 0.4688
# Batch no: 076, Loss on trainig: 2.1650, Accuracy: 0.4062
# Batch no: 077, Loss on trainig: 2.2695, Accuracy: 0.3906
# Batch no: 078, Loss on trainig: 2.1026, Accuracy: 0.4688
# Batch no: 079, Loss on trainig: 1.9405, Accuracy: 0.5156
# Batch no: 080, Loss on trainig: 1.7561, Accuracy: 0.5469
# Batch no: 081, Loss on trainig: 1.7956, Accuracy: 0.5000
# Batch no: 082, Loss on trainig: 2.2182, Accuracy: 0.3906
# Batch no: 083, Loss on trainig: 2.0622, Accuracy: 0.4375
# Batch no: 084, Loss on trainig: 2.5489, Accuracy: 0.3906
# Batch no: 085, Loss on trainig: 1.9254, Accuracy: 0.4531
# Batch no: 086, Loss on trainig: 2.4125, Accuracy: 0.3281
# Batch no: 087, Loss on trainig: 2.4042, Accuracy: 0.3594
# Batch no: 088, Loss on trainig: 2.1100, Accuracy: 0.4062
# Batch no: 089, Loss on trainig: 1.9298, Accuracy: 0.4531
# Batch no: 090, Loss on trainig: 2.6211, Accuracy: 0.2812
# Batch no: 091, Loss on trainig: 2.5531, Accuracy: 0.3438
# Batch no: 092, Loss on trainig: 1.9499, Accuracy: 0.4219
# Batch no: 093, Loss on trainig: 2.3644, Accuracy: 0.4219
# Batch no: 094, Loss on trainig: 2.0323, Accuracy: 0.4531
# Batch no: 095, Loss on trainig: 1.9915, Accuracy: 0.4531
# Batch no: 096, Loss on trainig: 2.0373, Accuracy: 0.5312
# Batch no: 097, Loss on trainig: 2.0306, Accuracy: 0.4688
# Batch no: 098, Loss on trainig: 2.0277, Accuracy: 0.4531
# Batch no: 099, Loss on trainig: 2.3910, Accuracy: 0.3750
# Batch no: 100, Loss on trainig: 2.3157, Accuracy: 0.3594
# Batch no: 101, Loss on trainig: 2.3651, Accuracy: 0.2969
# Batch no: 102, Loss on trainig: 2.0149, Accuracy: 0.5000
# Epoch: 4/18
# Batch no: 000, Loss on trainig: 2.1298, Accuracy: 0.4375
# Batch no: 001, Loss on trainig: 2.1569, Accuracy: 0.4062
# Batch no: 002, Loss on trainig: 1.9633, Accuracy: 0.4531
# Batch no: 003, Loss on trainig: 2.5070, Accuracy: 0.4062
# Batch no: 004, Loss on trainig: 2.2367, Accuracy: 0.4219
# Batch no: 005, Loss on trainig: 2.4202, Accuracy: 0.3281
# Batch no: 006, Loss on trainig: 1.6941, Accuracy: 0.6094
# Batch no: 007, Loss on trainig: 2.3016, Accuracy: 0.2969
# Batch no: 008, Loss on trainig: 1.9928, Accuracy: 0.4062
# Batch no: 009, Loss on trainig: 2.0675, Accuracy: 0.4375
# Batch no: 010, Loss on trainig: 2.1082, Accuracy: 0.4062
# Batch no: 011, Loss on trainig: 2.0700, Accuracy: 0.5312
# Batch no: 012, Loss on trainig: 1.8563, Accuracy: 0.4844
# Batch no: 013, Loss on trainig: 1.9064, Accuracy: 0.4688
# Batch no: 014, Loss on trainig: 1.9922, Accuracy: 0.4844
# Batch no: 015, Loss on trainig: 1.9415, Accuracy: 0.4375
# Batch no: 016, Loss on trainig: 2.0392, Accuracy: 0.4531
# Batch no: 017, Loss on trainig: 1.8517, Accuracy: 0.5000
# Batch no: 018, Loss on trainig: 2.2677, Accuracy: 0.4062
# Batch no: 019, Loss on trainig: 2.1047, Accuracy: 0.4062
# Batch no: 020, Loss on trainig: 2.3593, Accuracy: 0.3594
# Batch no: 021, Loss on trainig: 2.1047, Accuracy: 0.3438
# Batch no: 022, Loss on trainig: 2.0349, Accuracy: 0.3906
# Batch no: 023, Loss on trainig: 2.2357, Accuracy: 0.3281
# Batch no: 024, Loss on trainig: 2.1298, Accuracy: 0.4531
# Batch no: 025, Loss on trainig: 2.0959, Accuracy: 0.4531
# Batch no: 026, Loss on trainig: 2.1020, Accuracy: 0.4688
# Batch no: 027, Loss on trainig: 1.9642, Accuracy: 0.4688
# Batch no: 028, Loss on trainig: 2.3057, Accuracy: 0.3594
# Batch no: 029, Loss on trainig: 2.2163, Accuracy: 0.4531
# Batch no: 030, Loss on trainig: 2.5349, Accuracy: 0.3438
# Batch no: 031, Loss on trainig: 2.2395, Accuracy: 0.4531
# Batch no: 032, Loss on trainig: 2.2114, Accuracy: 0.4062
# Batch no: 033, Loss on trainig: 2.3555, Accuracy: 0.3906
# Batch no: 034, Loss on trainig: 1.9271, Accuracy: 0.4531
# Batch no: 035, Loss on trainig: 1.7064, Accuracy: 0.5938
# Batch no: 036, Loss on trainig: 2.2442, Accuracy: 0.3594
# Batch no: 037, Loss on trainig: 2.2028, Accuracy: 0.3906
# Batch no: 038, Loss on trainig: 2.0488, Accuracy: 0.4219
# Batch no: 039, Loss on trainig: 2.1434, Accuracy: 0.4062
# Batch no: 040, Loss on trainig: 2.0647, Accuracy: 0.4531
# Batch no: 041, Loss on trainig: 2.5131, Accuracy: 0.2812
# Batch no: 042, Loss on trainig: 1.6059, Accuracy: 0.5781
# Batch no: 043, Loss on trainig: 1.8866, Accuracy: 0.5156
# Batch no: 044, Loss on trainig: 2.0234, Accuracy: 0.4375
# Batch no: 045, Loss on trainig: 1.8989, Accuracy: 0.5312
# Batch no: 046, Loss on trainig: 1.8194, Accuracy: 0.5312
# Batch no: 047, Loss on trainig: 2.1992, Accuracy: 0.4375
# Batch no: 048, Loss on trainig: 2.1648, Accuracy: 0.4688
# Batch no: 049, Loss on trainig: 2.2982, Accuracy: 0.3594
# Batch no: 050, Loss on trainig: 2.3679, Accuracy: 0.3438
# Batch no: 051, Loss on trainig: 1.9719, Accuracy: 0.4219
# Batch no: 052, Loss on trainig: 2.0766, Accuracy: 0.4375
# Batch no: 053, Loss on trainig: 1.9444, Accuracy: 0.5000
# Batch no: 054, Loss on trainig: 2.3189, Accuracy: 0.3438
# Batch no: 055, Loss on trainig: 2.3023, Accuracy: 0.3906
# Batch no: 056, Loss on trainig: 1.9849, Accuracy: 0.4531
# Batch no: 057, Loss on trainig: 2.2259, Accuracy: 0.4219
# Batch no: 058, Loss on trainig: 2.0741, Accuracy: 0.4062
# Batch no: 059, Loss on trainig: 2.3316, Accuracy: 0.3906
# Batch no: 060, Loss on trainig: 2.1597, Accuracy: 0.4219
# Batch no: 061, Loss on trainig: 1.9119, Accuracy: 0.5469
# Batch no: 062, Loss on trainig: 1.7444, Accuracy: 0.5156
# Batch no: 063, Loss on trainig: 1.7849, Accuracy: 0.4531
# Batch no: 064, Loss on trainig: 2.0715, Accuracy: 0.4688
# Batch no: 065, Loss on trainig: 2.1650, Accuracy: 0.4531
# Batch no: 066, Loss on trainig: 1.9842, Accuracy: 0.4844
# Batch no: 067, Loss on trainig: 2.0013, Accuracy: 0.5312
# Batch no: 068, Loss on trainig: 1.7659, Accuracy: 0.5156
# Batch no: 069, Loss on trainig: 2.0923, Accuracy: 0.4219
# Batch no: 070, Loss on trainig: 1.8628, Accuracy: 0.5156
# Batch no: 071, Loss on trainig: 1.8653, Accuracy: 0.4688
# Batch no: 072, Loss on trainig: 2.2239, Accuracy: 0.3906
# Batch no: 073, Loss on trainig: 2.1595, Accuracy: 0.4219
# Batch no: 074, Loss on trainig: 2.2833, Accuracy: 0.3594
# Batch no: 075, Loss on trainig: 1.7039, Accuracy: 0.5469
# Batch no: 076, Loss on trainig: 2.4823, Accuracy: 0.4219
# Batch no: 077, Loss on trainig: 2.0861, Accuracy: 0.4531
# Batch no: 078, Loss on trainig: 2.2242, Accuracy: 0.4531
# Batch no: 079, Loss on trainig: 1.7198, Accuracy: 0.4531
# Batch no: 080, Loss on trainig: 1.8275, Accuracy: 0.4531
# Batch no: 081, Loss on trainig: 1.9547, Accuracy: 0.3906
# Batch no: 082, Loss on trainig: 1.7861, Accuracy: 0.5625
# Batch no: 083, Loss on trainig: 1.9868, Accuracy: 0.4844
# Batch no: 084, Loss on trainig: 2.3897, Accuracy: 0.3750
# Batch no: 085, Loss on trainig: 2.1948, Accuracy: 0.3906
# Batch no: 086, Loss on trainig: 2.2385, Accuracy: 0.3906
# Batch no: 087, Loss on trainig: 1.9241, Accuracy: 0.5000
# Batch no: 088, Loss on trainig: 1.9694, Accuracy: 0.5000
# Batch no: 089, Loss on trainig: 1.9689, Accuracy: 0.4688
# Batch no: 090, Loss on trainig: 2.1146, Accuracy: 0.4062
# Batch no: 091, Loss on trainig: 1.9038, Accuracy: 0.5000
# Batch no: 092, Loss on trainig: 1.4670, Accuracy: 0.6250
# Batch no: 093, Loss on trainig: 1.9533, Accuracy: 0.3750
# Batch no: 094, Loss on trainig: 2.1033, Accuracy: 0.4844
# Batch no: 095, Loss on trainig: 1.8980, Accuracy: 0.5156
# Batch no: 096, Loss on trainig: 1.9311, Accuracy: 0.5469
# Batch no: 097, Loss on trainig: 2.0977, Accuracy: 0.3906
# Batch no: 098, Loss on trainig: 2.1623, Accuracy: 0.4219
# Batch no: 099, Loss on trainig: 1.8227, Accuracy: 0.5156
# Batch no: 100, Loss on trainig: 1.7923, Accuracy: 0.5156
# Batch no: 101, Loss on trainig: 2.0327, Accuracy: 0.4531
# Batch no: 102, Loss on trainig: 2.1360, Accuracy: 0.5000
# Epoch: 5/18
# Batch no: 000, Loss on trainig: 1.9437, Accuracy: 0.4219
# Batch no: 001, Loss on trainig: 1.8159, Accuracy: 0.4531
# Batch no: 002, Loss on trainig: 1.7696, Accuracy: 0.4844
# Batch no: 003, Loss on trainig: 2.1481, Accuracy: 0.4062
# Batch no: 004, Loss on trainig: 1.7104, Accuracy: 0.5000
# Batch no: 005, Loss on trainig: 2.3892, Accuracy: 0.3906
# Batch no: 006, Loss on trainig: 1.5743, Accuracy: 0.5625
# Batch no: 007, Loss on trainig: 1.9817, Accuracy: 0.4375
# Batch no: 008, Loss on trainig: 2.2836, Accuracy: 0.4219
# Batch no: 009, Loss on trainig: 1.8723, Accuracy: 0.5000
# Batch no: 010, Loss on trainig: 1.9455, Accuracy: 0.4844
# Batch no: 011, Loss on trainig: 2.0559, Accuracy: 0.4688
# Batch no: 012, Loss on trainig: 1.7662, Accuracy: 0.4844
# Batch no: 013, Loss on trainig: 2.3327, Accuracy: 0.4531
# Batch no: 014, Loss on trainig: 1.8275, Accuracy: 0.5000
# Batch no: 015, Loss on trainig: 1.8679, Accuracy: 0.5312
# Batch no: 016, Loss on trainig: 1.7165, Accuracy: 0.5625
# Batch no: 017, Loss on trainig: 1.9379, Accuracy: 0.4062
# Batch no: 018, Loss on trainig: 2.0016, Accuracy: 0.4219
# Batch no: 019, Loss on trainig: 1.7858, Accuracy: 0.5312
# Batch no: 020, Loss on trainig: 1.5714, Accuracy: 0.5938
# Batch no: 021, Loss on trainig: 2.6000, Accuracy: 0.3281
# Batch no: 022, Loss on trainig: 2.5447, Accuracy: 0.3594
# Batch no: 023, Loss on trainig: 1.8801, Accuracy: 0.5312
# Batch no: 024, Loss on trainig: 2.2686, Accuracy: 0.5469
# Batch no: 025, Loss on trainig: 1.7662, Accuracy: 0.5156
# Batch no: 026, Loss on trainig: 1.8078, Accuracy: 0.5469
# Batch no: 027, Loss on trainig: 2.1123, Accuracy: 0.4219
# Batch no: 028, Loss on trainig: 2.3443, Accuracy: 0.3125
# Batch no: 029, Loss on trainig: 1.9193, Accuracy: 0.5156
# Batch no: 030, Loss on trainig: 1.8471, Accuracy: 0.4844
# Batch no: 031, Loss on trainig: 2.1425, Accuracy: 0.4062
# Batch no: 032, Loss on trainig: 1.9832, Accuracy: 0.4375
# Batch no: 033, Loss on trainig: 2.0582, Accuracy: 0.3906
# Batch no: 034, Loss on trainig: 1.6670, Accuracy: 0.5156
# Batch no: 035, Loss on trainig: 2.1706, Accuracy: 0.4219
# Batch no: 036, Loss on trainig: 1.8183, Accuracy: 0.5469
# Batch no: 037, Loss on trainig: 2.1019, Accuracy: 0.3906
# Batch no: 038, Loss on trainig: 2.0753, Accuracy: 0.3906
# Batch no: 039, Loss on trainig: 1.9276, Accuracy: 0.4844
# Batch no: 040, Loss on trainig: 2.0855, Accuracy: 0.4375
# Batch no: 041, Loss on trainig: 1.9103, Accuracy: 0.5156
# Batch no: 042, Loss on trainig: 1.9723, Accuracy: 0.4375
# Batch no: 043, Loss on trainig: 1.7746, Accuracy: 0.4219
# Batch no: 044, Loss on trainig: 1.9698, Accuracy: 0.5000
# Batch no: 045, Loss on trainig: 1.7022, Accuracy: 0.5000
# Batch no: 046, Loss on trainig: 1.8257, Accuracy: 0.4844
# Batch no: 047, Loss on trainig: 2.0818, Accuracy: 0.4375
# Batch no: 048, Loss on trainig: 1.8696, Accuracy: 0.4531
# Batch no: 049, Loss on trainig: 2.1055, Accuracy: 0.4219
# Batch no: 050, Loss on trainig: 1.9707, Accuracy: 0.4375
# Batch no: 051, Loss on trainig: 1.6071, Accuracy: 0.5312
# Batch no: 052, Loss on trainig: 1.7518, Accuracy: 0.4844
# Batch no: 053, Loss on trainig: 1.6698, Accuracy: 0.5312
# Batch no: 054, Loss on trainig: 2.4676, Accuracy: 0.3594
# Batch no: 055, Loss on trainig: 1.8444, Accuracy: 0.5000
# Batch no: 056, Loss on trainig: 1.7911, Accuracy: 0.5000
# Batch no: 057, Loss on trainig: 1.8741, Accuracy: 0.5156
# Batch no: 058, Loss on trainig: 2.0235, Accuracy: 0.5000
# Batch no: 059, Loss on trainig: 1.7918, Accuracy: 0.5469
# Batch no: 060, Loss on trainig: 1.7929, Accuracy: 0.5000
# Batch no: 061, Loss on trainig: 1.8729, Accuracy: 0.5938
# Batch no: 062, Loss on trainig: 1.9362, Accuracy: 0.4844
# Batch no: 063, Loss on trainig: 1.7222, Accuracy: 0.5469
# Batch no: 064, Loss on trainig: 1.8205, Accuracy: 0.4844
# Batch no: 065, Loss on trainig: 1.9973, Accuracy: 0.4531
# Batch no: 066, Loss on trainig: 1.9012, Accuracy: 0.5000
# Batch no: 067, Loss on trainig: 2.2964, Accuracy: 0.3906
# Batch no: 068, Loss on trainig: 1.5219, Accuracy: 0.6250
# Batch no: 069, Loss on trainig: 1.8978, Accuracy: 0.5000
# Batch no: 070, Loss on trainig: 1.8315, Accuracy: 0.5156
# Batch no: 071, Loss on trainig: 1.9341, Accuracy: 0.5312
# Batch no: 072, Loss on trainig: 2.1278, Accuracy: 0.4219
# Batch no: 073, Loss on trainig: 2.0960, Accuracy: 0.4844
# Batch no: 074, Loss on trainig: 2.3842, Accuracy: 0.4219
# Batch no: 075, Loss on trainig: 1.9449, Accuracy: 0.5156
# Batch no: 076, Loss on trainig: 2.1295, Accuracy: 0.4219
# Batch no: 077, Loss on trainig: 2.0661, Accuracy: 0.4531
# Batch no: 078, Loss on trainig: 1.7472, Accuracy: 0.4844
# Batch no: 079, Loss on trainig: 1.7660, Accuracy: 0.4375
# Batch no: 080, Loss on trainig: 1.9257, Accuracy: 0.4844
# Batch no: 081, Loss on trainig: 2.0912, Accuracy: 0.4219
# Batch no: 082, Loss on trainig: 2.1198, Accuracy: 0.4688
# Batch no: 083, Loss on trainig: 1.7962, Accuracy: 0.5469
# Batch no: 084, Loss on trainig: 1.9165, Accuracy: 0.5000
# Batch no: 085, Loss on trainig: 2.1793, Accuracy: 0.4375
# Batch no: 086, Loss on trainig: 1.9251, Accuracy: 0.5312
# Batch no: 087, Loss on trainig: 1.5994, Accuracy: 0.5312
# Batch no: 088, Loss on trainig: 1.7691, Accuracy: 0.4531
# Batch no: 089, Loss on trainig: 1.2951, Accuracy: 0.6406
# Batch no: 090, Loss on trainig: 2.1187, Accuracy: 0.4688
# Batch no: 091, Loss on trainig: 1.7243, Accuracy: 0.5000
# Batch no: 092, Loss on trainig: 2.1238, Accuracy: 0.4688
# Batch no: 093, Loss on trainig: 1.9252, Accuracy: 0.4844
# Batch no: 094, Loss on trainig: 1.7579, Accuracy: 0.5938
# Batch no: 095, Loss on trainig: 1.5251, Accuracy: 0.5625
# Batch no: 096, Loss on trainig: 2.1121, Accuracy: 0.4688
# Batch no: 097, Loss on trainig: 1.9545, Accuracy: 0.4375
# Batch no: 098, Loss on trainig: 1.7872, Accuracy: 0.4844
# Batch no: 099, Loss on trainig: 1.5597, Accuracy: 0.5625
# Batch no: 100, Loss on trainig: 1.6864, Accuracy: 0.5312
# Batch no: 101, Loss on trainig: 2.3183, Accuracy: 0.4062
# Batch no: 102, Loss on trainig: 1.6305, Accuracy: 0.6667
# Epoch: 6/18
# Batch no: 000, Loss on trainig: 1.4963, Accuracy: 0.6250
# Batch no: 001, Loss on trainig: 1.6493, Accuracy: 0.5312
# Batch no: 002, Loss on trainig: 1.6181, Accuracy: 0.5625
# Batch no: 003, Loss on trainig: 1.7318, Accuracy: 0.4688
# Batch no: 004, Loss on trainig: 1.7814, Accuracy: 0.5312
# Batch no: 005, Loss on trainig: 1.5900, Accuracy: 0.5156
# Batch no: 006, Loss on trainig: 2.0310, Accuracy: 0.5000
# Batch no: 007, Loss on trainig: 1.5088, Accuracy: 0.5469
# Batch no: 008, Loss on trainig: 1.6496, Accuracy: 0.5000
# Batch no: 009, Loss on trainig: 2.0221, Accuracy: 0.4688
# Batch no: 010, Loss on trainig: 1.6912, Accuracy: 0.5312
# Batch no: 011, Loss on trainig: 1.9325, Accuracy: 0.5000
# Batch no: 012, Loss on trainig: 1.8918, Accuracy: 0.4219
# Batch no: 013, Loss on trainig: 1.7481, Accuracy: 0.5156
# Batch no: 014, Loss on trainig: 1.8399, Accuracy: 0.4688
# Batch no: 015, Loss on trainig: 1.9993, Accuracy: 0.4531
# Batch no: 016, Loss on trainig: 1.8824, Accuracy: 0.5000
# Batch no: 017, Loss on trainig: 2.0758, Accuracy: 0.4844
# Batch no: 018, Loss on trainig: 1.7980, Accuracy: 0.5000
# Batch no: 019, Loss on trainig: 1.8145, Accuracy: 0.3906
# Batch no: 020, Loss on trainig: 1.5377, Accuracy: 0.5938
# Batch no: 021, Loss on trainig: 1.5437, Accuracy: 0.5312
# Batch no: 022, Loss on trainig: 1.5832, Accuracy: 0.5625
# Batch no: 023, Loss on trainig: 1.9901, Accuracy: 0.4375
# Batch no: 024, Loss on trainig: 1.7985, Accuracy: 0.4531
# Batch no: 025, Loss on trainig: 1.6784, Accuracy: 0.5156
# Batch no: 026, Loss on trainig: 1.4261, Accuracy: 0.6406
# Batch no: 027, Loss on trainig: 1.5937, Accuracy: 0.5625
# Batch no: 028, Loss on trainig: 2.0781, Accuracy: 0.4375
# Batch no: 029, Loss on trainig: 1.9517, Accuracy: 0.4219
# Batch no: 030, Loss on trainig: 1.8144, Accuracy: 0.4844
# Batch no: 031, Loss on trainig: 1.7853, Accuracy: 0.4219
# Batch no: 032, Loss on trainig: 1.3354, Accuracy: 0.6250
# Batch no: 033, Loss on trainig: 1.7278, Accuracy: 0.5156
# Batch no: 034, Loss on trainig: 1.9879, Accuracy: 0.4688
# Batch no: 035, Loss on trainig: 1.9921, Accuracy: 0.4531
# Batch no: 036, Loss on trainig: 1.7794, Accuracy: 0.4844
# Batch no: 037, Loss on trainig: 1.6065, Accuracy: 0.5156
# Batch no: 038, Loss on trainig: 1.6427, Accuracy: 0.6094
# Batch no: 039, Loss on trainig: 1.7849, Accuracy: 0.5312
# Batch no: 040, Loss on trainig: 1.4759, Accuracy: 0.6406
# Batch no: 041, Loss on trainig: 1.7249, Accuracy: 0.5156
# Batch no: 042, Loss on trainig: 2.0925, Accuracy: 0.4844
# Batch no: 043, Loss on trainig: 2.1604, Accuracy: 0.4531
# Batch no: 044, Loss on trainig: 1.1764, Accuracy: 0.6562
# Batch no: 045, Loss on trainig: 1.4904, Accuracy: 0.6094
# Batch no: 046, Loss on trainig: 1.7804, Accuracy: 0.4844
# Batch no: 047, Loss on trainig: 1.4924, Accuracy: 0.6094
# Batch no: 048, Loss on trainig: 1.9300, Accuracy: 0.4844
# Batch no: 049, Loss on trainig: 1.4464, Accuracy: 0.5625
# Batch no: 050, Loss on trainig: 1.6835, Accuracy: 0.5000
# Batch no: 051, Loss on trainig: 1.7699, Accuracy: 0.5156
# Batch no: 052, Loss on trainig: 1.8884, Accuracy: 0.4375
# Batch no: 053, Loss on trainig: 2.1005, Accuracy: 0.5156
# Batch no: 054, Loss on trainig: 1.7619, Accuracy: 0.5156
# Batch no: 055, Loss on trainig: 1.9737, Accuracy: 0.5469
# Batch no: 056, Loss on trainig: 1.6186, Accuracy: 0.5781
# Batch no: 057, Loss on trainig: 1.7362, Accuracy: 0.5156
# Batch no: 058, Loss on trainig: 1.6992, Accuracy: 0.5781
# Batch no: 059, Loss on trainig: 2.2077, Accuracy: 0.4062
# Batch no: 060, Loss on trainig: 1.5616, Accuracy: 0.5469
# Batch no: 061, Loss on trainig: 1.6463, Accuracy: 0.4844
# Batch no: 062, Loss on trainig: 1.5529, Accuracy: 0.5938
# Batch no: 063, Loss on trainig: 1.7294, Accuracy: 0.5469
# Batch no: 064, Loss on trainig: 1.6149, Accuracy: 0.5938
# Batch no: 065, Loss on trainig: 1.9014, Accuracy: 0.4062
# Batch no: 066, Loss on trainig: 1.7772, Accuracy: 0.4531
# Batch no: 067, Loss on trainig: 2.0204, Accuracy: 0.4844
# Batch no: 068, Loss on trainig: 1.6522, Accuracy: 0.4531
# Batch no: 069, Loss on trainig: 1.6257, Accuracy: 0.5781
# Batch no: 070, Loss on trainig: 1.3094, Accuracy: 0.6094
# Batch no: 071, Loss on trainig: 1.8625, Accuracy: 0.3906
# Batch no: 072, Loss on trainig: 2.1452, Accuracy: 0.5000
# Batch no: 073, Loss on trainig: 1.8296, Accuracy: 0.4844
# Batch no: 074, Loss on trainig: 1.6670, Accuracy: 0.5000
# Batch no: 075, Loss on trainig: 1.7620, Accuracy: 0.4688
# Batch no: 076, Loss on trainig: 1.9812, Accuracy: 0.4531
# Batch no: 077, Loss on trainig: 1.7663, Accuracy: 0.5469
# Batch no: 078, Loss on trainig: 1.9841, Accuracy: 0.4219
# Batch no: 079, Loss on trainig: 2.0045, Accuracy: 0.4375
# Batch no: 080, Loss on trainig: 1.6291, Accuracy: 0.5781
# Batch no: 081, Loss on trainig: 2.1870, Accuracy: 0.4375
# Batch no: 082, Loss on trainig: 1.6314, Accuracy: 0.5000
# Batch no: 083, Loss on trainig: 1.8524, Accuracy: 0.4531
# Batch no: 084, Loss on trainig: 1.8126, Accuracy: 0.5000
# Batch no: 085, Loss on trainig: 1.7533, Accuracy: 0.5312
# Batch no: 086, Loss on trainig: 1.4813, Accuracy: 0.5781
# Batch no: 087, Loss on trainig: 1.9597, Accuracy: 0.5312
# Batch no: 088, Loss on trainig: 1.6896, Accuracy: 0.5156
# Batch no: 089, Loss on trainig: 1.7847, Accuracy: 0.5469
# Batch no: 090, Loss on trainig: 1.6377, Accuracy: 0.5156
# Batch no: 091, Loss on trainig: 2.0534, Accuracy: 0.5469
# Batch no: 092, Loss on trainig: 2.1181, Accuracy: 0.4531
# Batch no: 093, Loss on trainig: 1.4834, Accuracy: 0.6250
# Batch no: 094, Loss on trainig: 1.5058, Accuracy: 0.5469
# Batch no: 095, Loss on trainig: 1.9442, Accuracy: 0.4219
# Batch no: 096, Loss on trainig: 1.6844, Accuracy: 0.5312
# Batch no: 097, Loss on trainig: 1.9557, Accuracy: 0.4375
# Batch no: 098, Loss on trainig: 1.7491, Accuracy: 0.5938
# Batch no: 099, Loss on trainig: 2.3759, Accuracy: 0.4219
# Batch no: 100, Loss on trainig: 1.9035, Accuracy: 0.4531
# Batch no: 101, Loss on trainig: 1.7508, Accuracy: 0.5469
# Batch no: 102, Loss on trainig: 1.7798, Accuracy: 0.5000
# Epoch: 7/18
# Batch no: 000, Loss on trainig: 1.5943, Accuracy: 0.4844
# Batch no: 001, Loss on trainig: 1.8637, Accuracy: 0.4531
# Batch no: 002, Loss on trainig: 1.7310, Accuracy: 0.5312
# Batch no: 003, Loss on trainig: 1.6867, Accuracy: 0.6094
# Batch no: 004, Loss on trainig: 1.7064, Accuracy: 0.5000
# Batch no: 005, Loss on trainig: 1.8489, Accuracy: 0.4688
# Batch no: 006, Loss on trainig: 1.7477, Accuracy: 0.4688
# Batch no: 007, Loss on trainig: 1.6638, Accuracy: 0.5781
# Batch no: 008, Loss on trainig: 1.7925, Accuracy: 0.5469
# Batch no: 009, Loss on trainig: 1.9626, Accuracy: 0.5000
# Batch no: 010, Loss on trainig: 1.5111, Accuracy: 0.5625
# Batch no: 011, Loss on trainig: 1.8544, Accuracy: 0.5625
# Batch no: 012, Loss on trainig: 1.8533, Accuracy: 0.4688
# Batch no: 013, Loss on trainig: 1.8248, Accuracy: 0.5156
# Batch no: 014, Loss on trainig: 2.0264, Accuracy: 0.4531
# Batch no: 015, Loss on trainig: 1.8126, Accuracy: 0.5625
# Batch no: 016, Loss on trainig: 1.9694, Accuracy: 0.4844
# Batch no: 017, Loss on trainig: 1.5183, Accuracy: 0.6406
# Batch no: 018, Loss on trainig: 1.7748, Accuracy: 0.5156
# Batch no: 019, Loss on trainig: 2.1431, Accuracy: 0.4219
# Batch no: 020, Loss on trainig: 1.3603, Accuracy: 0.6094
# Batch no: 021, Loss on trainig: 1.8566, Accuracy: 0.4688
# Batch no: 022, Loss on trainig: 1.9511, Accuracy: 0.4844
# Batch no: 023, Loss on trainig: 1.6677, Accuracy: 0.5469
# Batch no: 024, Loss on trainig: 1.8313, Accuracy: 0.4844
# Batch no: 025, Loss on trainig: 1.4493, Accuracy: 0.5625
# Batch no: 026, Loss on trainig: 1.5025, Accuracy: 0.6406
# Batch no: 027, Loss on trainig: 1.5643, Accuracy: 0.5312
# Batch no: 028, Loss on trainig: 1.5664, Accuracy: 0.5781
# Batch no: 029, Loss on trainig: 2.0309, Accuracy: 0.4688
# Batch no: 030, Loss on trainig: 1.7489, Accuracy: 0.5781
# Batch no: 031, Loss on trainig: 1.5986, Accuracy: 0.6094
# Batch no: 032, Loss on trainig: 1.8751, Accuracy: 0.5469
# Batch no: 033, Loss on trainig: 1.6489, Accuracy: 0.5469
# Batch no: 034, Loss on trainig: 2.1702, Accuracy: 0.4062
# Batch no: 035, Loss on trainig: 1.9970, Accuracy: 0.3906
# Batch no: 036, Loss on trainig: 1.7334, Accuracy: 0.5781
# Batch no: 037, Loss on trainig: 1.8479, Accuracy: 0.5156
# Batch no: 038, Loss on trainig: 1.6813, Accuracy: 0.4844
# Batch no: 039, Loss on trainig: 1.6969, Accuracy: 0.5625
# Batch no: 040, Loss on trainig: 1.3335, Accuracy: 0.6094
# Batch no: 041, Loss on trainig: 1.6151, Accuracy: 0.5312
# Batch no: 042, Loss on trainig: 1.4980, Accuracy: 0.5781
# Batch no: 043, Loss on trainig: 1.8914, Accuracy: 0.4531
# Batch no: 044, Loss on trainig: 1.5409, Accuracy: 0.5625
# Batch no: 045, Loss on trainig: 1.7694, Accuracy: 0.5469
# Batch no: 046, Loss on trainig: 1.6995, Accuracy: 0.5000
# Batch no: 047, Loss on trainig: 1.3559, Accuracy: 0.6562
# Batch no: 048, Loss on trainig: 1.6683, Accuracy: 0.4844
# Batch no: 049, Loss on trainig: 1.7537, Accuracy: 0.5938
# Batch no: 050, Loss on trainig: 1.6959, Accuracy: 0.4844
# Batch no: 051, Loss on trainig: 1.7856, Accuracy: 0.5156
# Batch no: 052, Loss on trainig: 2.1381, Accuracy: 0.4688
# Batch no: 053, Loss on trainig: 1.7468, Accuracy: 0.5156
# Batch no: 054, Loss on trainig: 1.6304, Accuracy: 0.4688
# Batch no: 055, Loss on trainig: 1.6120, Accuracy: 0.6250
# Batch no: 056, Loss on trainig: 1.6008, Accuracy: 0.5312
# Batch no: 057, Loss on trainig: 1.9826, Accuracy: 0.4688
# Batch no: 058, Loss on trainig: 1.4981, Accuracy: 0.5781
# Batch no: 059, Loss on trainig: 2.0174, Accuracy: 0.4531
# Batch no: 060, Loss on trainig: 1.8217, Accuracy: 0.5312
# Batch no: 061, Loss on trainig: 1.8832, Accuracy: 0.5625
# Batch no: 062, Loss on trainig: 1.9040, Accuracy: 0.5312
# Batch no: 063, Loss on trainig: 1.7971, Accuracy: 0.5000
# Batch no: 064, Loss on trainig: 1.7811, Accuracy: 0.4844
# Batch no: 065, Loss on trainig: 1.6049, Accuracy: 0.5625
# Batch no: 066, Loss on trainig: 2.3786, Accuracy: 0.4062
# Batch no: 067, Loss on trainig: 1.8337, Accuracy: 0.4844
# Batch no: 068, Loss on trainig: 1.6734, Accuracy: 0.5312
# Batch no: 069, Loss on trainig: 1.8240, Accuracy: 0.5312
# Batch no: 070, Loss on trainig: 1.9258, Accuracy: 0.5000
# Batch no: 071, Loss on trainig: 1.7653, Accuracy: 0.4844
# Batch no: 072, Loss on trainig: 1.3313, Accuracy: 0.6875
# Batch no: 073, Loss on trainig: 1.7557, Accuracy: 0.4844
# Batch no: 074, Loss on trainig: 1.7945, Accuracy: 0.4375
# Batch no: 075, Loss on trainig: 1.7106, Accuracy: 0.4844
# Batch no: 076, Loss on trainig: 1.7105, Accuracy: 0.5625
# Batch no: 077, Loss on trainig: 1.4986, Accuracy: 0.5312
# Batch no: 078, Loss on trainig: 1.4880, Accuracy: 0.5469
# Batch no: 079, Loss on trainig: 1.7568, Accuracy: 0.4531
# Batch no: 080, Loss on trainig: 1.3958, Accuracy: 0.5938
# Batch no: 081, Loss on trainig: 1.4730, Accuracy: 0.6562
# Batch no: 082, Loss on trainig: 1.5599, Accuracy: 0.5625
# Batch no: 083, Loss on trainig: 1.6316, Accuracy: 0.5156
# Batch no: 084, Loss on trainig: 1.5477, Accuracy: 0.5469
# Batch no: 085, Loss on trainig: 1.9571, Accuracy: 0.5156
# Batch no: 086, Loss on trainig: 1.8288, Accuracy: 0.5312
# Batch no: 087, Loss on trainig: 1.8113, Accuracy: 0.5156
# Batch no: 088, Loss on trainig: 1.6409, Accuracy: 0.5156
# Batch no: 089, Loss on trainig: 1.6056, Accuracy: 0.5469
# Batch no: 090, Loss on trainig: 1.8653, Accuracy: 0.5156
# Batch no: 091, Loss on trainig: 1.4212, Accuracy: 0.5781
# Batch no: 092, Loss on trainig: 1.5570, Accuracy: 0.5312
# Batch no: 093, Loss on trainig: 1.6329, Accuracy: 0.6250
# Batch no: 094, Loss on trainig: 2.1056, Accuracy: 0.4062
# Batch no: 095, Loss on trainig: 1.6730, Accuracy: 0.5000
# Batch no: 096, Loss on trainig: 1.5560, Accuracy: 0.5781
# Batch no: 097, Loss on trainig: 1.3025, Accuracy: 0.5938
# Batch no: 098, Loss on trainig: 1.3670, Accuracy: 0.6406
# Batch no: 099, Loss on trainig: 1.5599, Accuracy: 0.5469
# Batch no: 100, Loss on trainig: 1.4720, Accuracy: 0.5625
# Batch no: 101, Loss on trainig: 1.7773, Accuracy: 0.6094
# Batch no: 102, Loss on trainig: 1.5168, Accuracy: 0.5833
# Epoch: 8/18
# Batch no: 000, Loss on trainig: 1.3945, Accuracy: 0.6406
# Batch no: 001, Loss on trainig: 1.7770, Accuracy: 0.5000
# Batch no: 002, Loss on trainig: 1.8170, Accuracy: 0.5000
# Batch no: 003, Loss on trainig: 1.6025, Accuracy: 0.5938
# Batch no: 004, Loss on trainig: 1.6850, Accuracy: 0.5312
# Batch no: 005, Loss on trainig: 2.3191, Accuracy: 0.3281
# Batch no: 006, Loss on trainig: 1.5802, Accuracy: 0.5000
# Batch no: 007, Loss on trainig: 1.6836, Accuracy: 0.5469
# Batch no: 008, Loss on trainig: 2.0082, Accuracy: 0.4844
# Batch no: 009, Loss on trainig: 2.1037, Accuracy: 0.4375
# Batch no: 010, Loss on trainig: 1.8654, Accuracy: 0.5000
# Batch no: 011, Loss on trainig: 1.7079, Accuracy: 0.4688
# Batch no: 012, Loss on trainig: 2.0325, Accuracy: 0.3906
# Batch no: 013, Loss on trainig: 1.6249, Accuracy: 0.5312
# Batch no: 014, Loss on trainig: 1.4574, Accuracy: 0.6094
# Batch no: 015, Loss on trainig: 1.9139, Accuracy: 0.4375
# Batch no: 016, Loss on trainig: 1.4526, Accuracy: 0.6250
# Batch no: 017, Loss on trainig: 2.0388, Accuracy: 0.4531
# Batch no: 018, Loss on trainig: 1.5769, Accuracy: 0.5781
# Batch no: 019, Loss on trainig: 1.6009, Accuracy: 0.5469
# Batch no: 020, Loss on trainig: 1.5214, Accuracy: 0.5781
# Batch no: 021, Loss on trainig: 1.3295, Accuracy: 0.5938
# Batch no: 022, Loss on trainig: 1.8167, Accuracy: 0.5625
# Batch no: 023, Loss on trainig: 1.3005, Accuracy: 0.6562
# Batch no: 024, Loss on trainig: 1.4885, Accuracy: 0.5781
# Batch no: 025, Loss on trainig: 1.6365, Accuracy: 0.5781
# Batch no: 026, Loss on trainig: 1.3949, Accuracy: 0.5781
# Batch no: 027, Loss on trainig: 1.3249, Accuracy: 0.6250
# Batch no: 028, Loss on trainig: 2.0166, Accuracy: 0.4062
# Batch no: 029, Loss on trainig: 1.5080, Accuracy: 0.5938
# Batch no: 030, Loss on trainig: 1.3272, Accuracy: 0.5312
# Batch no: 031, Loss on trainig: 1.5326, Accuracy: 0.6094
# Batch no: 032, Loss on trainig: 1.8519, Accuracy: 0.4844
# Batch no: 033, Loss on trainig: 1.5696, Accuracy: 0.5781
# Batch no: 034, Loss on trainig: 1.9088, Accuracy: 0.4375
# Batch no: 035, Loss on trainig: 1.8167, Accuracy: 0.5312
# Batch no: 036, Loss on trainig: 1.3424, Accuracy: 0.6250
# Batch no: 037, Loss on trainig: 1.2933, Accuracy: 0.6875
# Batch no: 038, Loss on trainig: 1.3886, Accuracy: 0.5469
# Batch no: 039, Loss on trainig: 1.5349, Accuracy: 0.5312
# Batch no: 040, Loss on trainig: 1.4862, Accuracy: 0.6406
# Batch no: 041, Loss on trainig: 1.6283, Accuracy: 0.5625
# Batch no: 042, Loss on trainig: 1.7265, Accuracy: 0.5312
# Batch no: 043, Loss on trainig: 1.9505, Accuracy: 0.5000
# Batch no: 044, Loss on trainig: 1.4864, Accuracy: 0.5938
# Batch no: 045, Loss on trainig: 1.4542, Accuracy: 0.5625
# Batch no: 046, Loss on trainig: 1.8861, Accuracy: 0.4219
# Batch no: 047, Loss on trainig: 1.4214, Accuracy: 0.6250
# Batch no: 048, Loss on trainig: 1.4467, Accuracy: 0.5938
# Batch no: 049, Loss on trainig: 1.6994, Accuracy: 0.4219
# Batch no: 050, Loss on trainig: 1.9258, Accuracy: 0.3906
# Batch no: 051, Loss on trainig: 2.0002, Accuracy: 0.4688
# Batch no: 052, Loss on trainig: 1.6485, Accuracy: 0.5156
# Batch no: 053, Loss on trainig: 2.0496, Accuracy: 0.4844
# Batch no: 054, Loss on trainig: 1.4398, Accuracy: 0.5625
# Batch no: 055, Loss on trainig: 1.8873, Accuracy: 0.5156
# Batch no: 056, Loss on trainig: 2.0219, Accuracy: 0.4688
# Batch no: 057, Loss on trainig: 1.5155, Accuracy: 0.5469
# Batch no: 058, Loss on trainig: 1.2696, Accuracy: 0.6719
# Batch no: 059, Loss on trainig: 1.6246, Accuracy: 0.6094
# Batch no: 060, Loss on trainig: 2.1036, Accuracy: 0.4062
# Batch no: 061, Loss on trainig: 1.7331, Accuracy: 0.5156
# Batch no: 062, Loss on trainig: 1.4485, Accuracy: 0.6562
# Batch no: 063, Loss on trainig: 1.6286, Accuracy: 0.5156
# Batch no: 064, Loss on trainig: 1.7080, Accuracy: 0.5625
# Batch no: 065, Loss on trainig: 1.6159, Accuracy: 0.5781
# Batch no: 066, Loss on trainig: 1.5351, Accuracy: 0.5469
# Batch no: 067, Loss on trainig: 1.2471, Accuracy: 0.6875
# Batch no: 068, Loss on trainig: 1.7613, Accuracy: 0.5312
# Batch no: 069, Loss on trainig: 1.5245, Accuracy: 0.5156
# Batch no: 070, Loss on trainig: 1.6371, Accuracy: 0.5312
# Batch no: 071, Loss on trainig: 2.4091, Accuracy: 0.4531
# Batch no: 072, Loss on trainig: 1.6951, Accuracy: 0.5000
# Batch no: 073, Loss on trainig: 1.8393, Accuracy: 0.4844
# Batch no: 074, Loss on trainig: 1.8699, Accuracy: 0.4219
# Batch no: 075, Loss on trainig: 1.9205, Accuracy: 0.4062
# Batch no: 076, Loss on trainig: 1.5123, Accuracy: 0.5156
# Batch no: 077, Loss on trainig: 2.1010, Accuracy: 0.4531
# Batch no: 078, Loss on trainig: 1.4519, Accuracy: 0.5625
# Batch no: 079, Loss on trainig: 1.7645, Accuracy: 0.5000
# Batch no: 080, Loss on trainig: 1.6400, Accuracy: 0.6094
# Batch no: 081, Loss on trainig: 1.9956, Accuracy: 0.5156
# Batch no: 082, Loss on trainig: 1.9728, Accuracy: 0.4688
# Batch no: 083, Loss on trainig: 1.7947, Accuracy: 0.5156
# Batch no: 084, Loss on trainig: 1.7548, Accuracy: 0.5156
# Batch no: 085, Loss on trainig: 1.9376, Accuracy: 0.5156
# Batch no: 086, Loss on trainig: 1.9244, Accuracy: 0.4531
# Batch no: 087, Loss on trainig: 1.5403, Accuracy: 0.5781
# Batch no: 088, Loss on trainig: 1.8991, Accuracy: 0.4531
# Batch no: 089, Loss on trainig: 1.6191, Accuracy: 0.5469
# Batch no: 090, Loss on trainig: 1.9022, Accuracy: 0.5000
# Batch no: 091, Loss on trainig: 1.5237, Accuracy: 0.5156
# Batch no: 092, Loss on trainig: 1.8771, Accuracy: 0.5000
# Batch no: 093, Loss on trainig: 1.6748, Accuracy: 0.5625
# Batch no: 094, Loss on trainig: 1.6301, Accuracy: 0.5312
# Batch no: 095, Loss on trainig: 1.4224, Accuracy: 0.6562
# Batch no: 096, Loss on trainig: 1.6325, Accuracy: 0.5469
# Batch no: 097, Loss on trainig: 1.5241, Accuracy: 0.5938
# Batch no: 098, Loss on trainig: 1.4461, Accuracy: 0.5781
# Batch no: 099, Loss on trainig: 1.0567, Accuracy: 0.7656
# Batch no: 100, Loss on trainig: 1.6277, Accuracy: 0.5156
# Batch no: 101, Loss on trainig: 1.8036, Accuracy: 0.5469
# Batch no: 102, Loss on trainig: 1.4451, Accuracy: 0.5833
# Epoch: 9/18
# Batch no: 000, Loss on trainig: 1.7636, Accuracy: 0.4844
# Batch no: 001, Loss on trainig: 1.5408, Accuracy: 0.5312
# Batch no: 002, Loss on trainig: 1.7433, Accuracy: 0.5000
# Batch no: 003, Loss on trainig: 1.2814, Accuracy: 0.5781
# Batch no: 004, Loss on trainig: 1.5462, Accuracy: 0.5469
# Batch no: 005, Loss on trainig: 1.8294, Accuracy: 0.4844
# Batch no: 006, Loss on trainig: 1.6742, Accuracy: 0.5156
# Batch no: 007, Loss on trainig: 1.3371, Accuracy: 0.6250
# Batch no: 008, Loss on trainig: 1.5246, Accuracy: 0.6250
# Batch no: 009, Loss on trainig: 1.5298, Accuracy: 0.5469
# Batch no: 010, Loss on trainig: 1.4312, Accuracy: 0.6562
# Batch no: 011, Loss on trainig: 1.1923, Accuracy: 0.7031
# Batch no: 012, Loss on trainig: 1.6052, Accuracy: 0.6094
# Batch no: 013, Loss on trainig: 2.1455, Accuracy: 0.4062
# Batch no: 014, Loss on trainig: 1.9923, Accuracy: 0.4844
# Batch no: 015, Loss on trainig: 1.7689, Accuracy: 0.5000
# ...
# Batch no: 029, Loss on trainig: 1.4684, Accuracy: 0.6406
# Batch no: 030, Loss on trainig: 1.4455, Accuracy: 0.5938
# Batch no: 031, Loss on trainig: 1.6979, Accuracy: 0.4688
# Batch no: 032, Loss on trainig: 1.3890, Accuracy: 0.5625
# Batch no: 033, Loss on trainig: 1.3322, Accuracy: 0.6562
# Batch no: 034, Loss on trainig: 1.5238, Accuracy: 0.5938
# Batch no: 035, Loss on trainig: 1.4158, Accuracy: 0.6406
# Batch no: 036, Loss on trainig: 1.0609, Accuracy: 0.6562
# Batch no: 037, Loss on trainig: 1.6159, Accuracy: 0.5312
# Batch no: 038, Loss on trainig: 1.1184, Accuracy: 0.6875
# Batch no: 039, Loss on trainig: 0.8754, Accuracy: 0.7656
# Batch no: 040, Loss on trainig: 1.4019, Accuracy: 0.6094
# Batch no: 041, Loss on trainig: 1.6229, Accuracy: 0.5156
# Batch no: 042, Loss on trainig: 1.3781, Accuracy: 0.6406
# Batch no: 043, Loss on trainig: 1.6030, Accuracy: 0.5781
# Batch no: 044, Loss on trainig: 1.1882, Accuracy: 0.6094
# Batch no: 045, Loss on trainig: 1.4567, Accuracy: 0.5781
# Batch no: 046, Loss on trainig: 1.3344, Accuracy: 0.6250
# Batch no: 047, Loss on trainig: 1.4853, Accuracy: 0.6250
# Batch no: 048, Loss on trainig: 1.7209, Accuracy: 0.5000
# Batch no: 049, Loss on trainig: 1.8355, Accuracy: 0.4844
# Batch no: 050, Loss on trainig: 1.7047, Accuracy: 0.5156
# Batch no: 051, Loss on trainig: 1.7768, Accuracy: 0.5781
# Batch no: 052, Loss on trainig: 1.2697, Accuracy: 0.6719
# Batch no: 053, Loss on trainig: 1.3180, Accuracy: 0.6719
# Batch no: 054, Loss on trainig: 1.3428, Accuracy: 0.5781
# Batch no: 055, Loss on trainig: 1.4048, Accuracy: 0.5469
# Batch no: 056, Loss on trainig: 1.4615, Accuracy: 0.5469
# Batch no: 057, Loss on trainig: 1.4269, Accuracy: 0.6562
# Batch no: 058, Loss on trainig: 1.4598, Accuracy: 0.6094
# Batch no: 059, Loss on trainig: 1.6626, Accuracy: 0.5000
# Batch no: 060, Loss on trainig: 1.4094, Accuracy: 0.5938
# Batch no: 061, Loss on trainig: 1.3697, Accuracy: 0.6250
# Batch no: 062, Loss on trainig: 1.5056, Accuracy: 0.5938
# Batch no: 063, Loss on trainig: 1.2723, Accuracy: 0.6562
# Batch no: 064, Loss on trainig: 1.4619, Accuracy: 0.5312
# Batch no: 065, Loss on trainig: 1.4456, Accuracy: 0.5938
# Batch no: 066, Loss on trainig: 1.3798, Accuracy: 0.6250
# Batch no: 067, Loss on trainig: 1.6369, Accuracy: 0.5469
# Batch no: 068, Loss on trainig: 1.3701, Accuracy: 0.6094
# Batch no: 069, Loss on trainig: 1.4138, Accuracy: 0.6094
# Batch no: 070, Loss on trainig: 1.8072, Accuracy: 0.5625
# Batch no: 071, Loss on trainig: 1.2476, Accuracy: 0.6406
# Batch no: 072, Loss on trainig: 1.6397, Accuracy: 0.5625
# Batch no: 073, Loss on trainig: 1.3852, Accuracy: 0.5625
# Batch no: 074, Loss on trainig: 1.5182, Accuracy: 0.5781
# Batch no: 075, Loss on trainig: 1.2173, Accuracy: 0.6562
# Batch no: 076, Loss on trainig: 1.3453, Accuracy: 0.7188
# Batch no: 077, Loss on trainig: 1.1349, Accuracy: 0.6406
# Batch no: 078, Loss on trainig: 1.4580, Accuracy: 0.5469
# Batch no: 079, Loss on trainig: 1.3518, Accuracy: 0.6094
# Batch no: 080, Loss on trainig: 1.2778, Accuracy: 0.6250
# Batch no: 081, Loss on trainig: 1.4159, Accuracy: 0.6250
# Batch no: 082, Loss on trainig: 1.9465, Accuracy: 0.5000
# Batch no: 083, Loss on trainig: 1.1378, Accuracy: 0.7188
# Batch no: 084, Loss on trainig: 1.0630, Accuracy: 0.7031
# Batch no: 085, Loss on trainig: 1.4920, Accuracy: 0.5625
# Batch no: 086, Loss on trainig: 1.3607, Accuracy: 0.5938
# Batch no: 087, Loss on trainig: 1.1117, Accuracy: 0.6406
# Batch no: 088, Loss on trainig: 1.5861, Accuracy: 0.6094
# Batch no: 089, Loss on trainig: 1.2792, Accuracy: 0.6562
# Batch no: 090, Loss on trainig: 1.4726, Accuracy: 0.6094
# Batch no: 091, Loss on trainig: 1.3781, Accuracy: 0.6562
# Batch no: 092, Loss on trainig: 1.4744, Accuracy: 0.5781
# Batch no: 093, Loss on trainig: 1.1662, Accuracy: 0.6719
# Batch no: 094, Loss on trainig: 1.6409, Accuracy: 0.5312
# Batch no: 095, Loss on trainig: 1.0872, Accuracy: 0.6562
# Batch no: 096, Loss on trainig: 1.0875, Accuracy: 0.6250
# Batch no: 097, Loss on trainig: 1.2665, Accuracy: 0.6406
# Batch no: 098, Loss on trainig: 1.3796, Accuracy: 0.5625
# Batch no: 099, Loss on trainig: 1.3694, Accuracy: 0.6562
# Batch no: 100, Loss on trainig: 1.6633, Accuracy: 0.5469
# Batch no: 101, Loss on trainig: 1.1200, Accuracy: 0.7188
# Batch no: 102, Loss on trainig: 1.8075, Accuracy: 0.6250
# Epoch: 17/18
# Batch no: 000, Loss on trainig: 1.6560, Accuracy: 0.5469
# Batch no: 001, Loss on trainig: 1.4680, Accuracy: 0.5938
# Batch no: 002, Loss on trainig: 1.6622, Accuracy: 0.5312
# Batch no: 003, Loss on trainig: 1.4371, Accuracy: 0.5156
# Batch no: 004, Loss on trainig: 1.0342, Accuracy: 0.7188
# Batch no: 005, Loss on trainig: 1.2966, Accuracy: 0.6406
# Batch no: 006, Loss on trainig: 1.1388, Accuracy: 0.5938
# Batch no: 007, Loss on trainig: 1.1177, Accuracy: 0.7188
# Batch no: 008, Loss on trainig: 1.4420, Accuracy: 0.5938
# Batch no: 009, Loss on trainig: 1.4975, Accuracy: 0.6406
# Batch no: 010, Loss on trainig: 1.5363, Accuracy: 0.5625
# Batch no: 011, Loss on trainig: 1.2429, Accuracy: 0.6719
# Batch no: 012, Loss on trainig: 1.2851, Accuracy: 0.6875
# Batch no: 013, Loss on trainig: 1.4340, Accuracy: 0.5625
# Batch no: 014, Loss on trainig: 1.4801, Accuracy: 0.6094
# Batch no: 015, Loss on trainig: 1.2285, Accuracy: 0.6875
# Batch no: 016, Loss on trainig: 1.6565, Accuracy: 0.5469
# Batch no: 017, Loss on trainig: 1.2713, Accuracy: 0.6094
# Batch no: 018, Loss on trainig: 1.5684, Accuracy: 0.5312
# Batch no: 019, Loss on trainig: 1.6259, Accuracy: 0.5781
# Batch no: 020, Loss on trainig: 1.2659, Accuracy: 0.6719
# Batch no: 021, Loss on trainig: 1.2822, Accuracy: 0.6562
# Batch no: 022, Loss on trainig: 1.4555, Accuracy: 0.6875
# Batch no: 023, Loss on trainig: 1.2773, Accuracy: 0.6094
# Batch no: 024, Loss on trainig: 1.1692, Accuracy: 0.6094
# Batch no: 025, Loss on trainig: 1.4675, Accuracy: 0.5625
# Batch no: 026, Loss on trainig: 1.4134, Accuracy: 0.5781
# Batch no: 027, Loss on trainig: 1.2753, Accuracy: 0.5938
# Batch no: 028, Loss on trainig: 1.3916, Accuracy: 0.6406
# Batch no: 029, Loss on trainig: 1.5266, Accuracy: 0.5938
# Batch no: 030, Loss on trainig: 1.5188, Accuracy: 0.5781
# Batch no: 031, Loss on trainig: 1.3744, Accuracy: 0.6406
# Batch no: 032, Loss on trainig: 1.3123, Accuracy: 0.6250
# Batch no: 033, Loss on trainig: 1.2623, Accuracy: 0.6562
# Batch no: 034, Loss on trainig: 1.1480, Accuracy: 0.6250
# Batch no: 035, Loss on trainig: 1.4230, Accuracy: 0.5938
# Batch no: 036, Loss on trainig: 1.1307, Accuracy: 0.6719
# Batch no: 037, Loss on trainig: 1.3443, Accuracy: 0.6875
# Batch no: 038, Loss on trainig: 1.6091, Accuracy: 0.5938
# Batch no: 039, Loss on trainig: 1.2047, Accuracy: 0.6094
# Batch no: 040, Loss on trainig: 1.4983, Accuracy: 0.5469
# Batch no: 041, Loss on trainig: 1.8719, Accuracy: 0.5000
# Batch no: 042, Loss on trainig: 1.4685, Accuracy: 0.6094
# Batch no: 043, Loss on trainig: 1.1394, Accuracy: 0.5938
# Batch no: 044, Loss on trainig: 1.3413, Accuracy: 0.6562
# Batch no: 045, Loss on trainig: 1.2290, Accuracy: 0.6875
# Batch no: 046, Loss on trainig: 1.6594, Accuracy: 0.6094
# Batch no: 047, Loss on trainig: 1.5990, Accuracy: 0.5469
# Batch no: 048, Loss on trainig: 1.3844, Accuracy: 0.5938
# Batch no: 049, Loss on trainig: 1.4743, Accuracy: 0.6562
# Batch no: 050, Loss on trainig: 1.9676, Accuracy: 0.4219
# Batch no: 051, Loss on trainig: 1.5958, Accuracy: 0.5469
# Batch no: 052, Loss on trainig: 1.6466, Accuracy: 0.5938
# Batch no: 053, Loss on trainig: 1.2405, Accuracy: 0.6250
# Batch no: 054, Loss on trainig: 0.9041, Accuracy: 0.7344
# Batch no: 055, Loss on trainig: 1.2180, Accuracy: 0.6875
# Batch no: 056, Loss on trainig: 1.4619, Accuracy: 0.6094
# Batch no: 057, Loss on trainig: 1.6284, Accuracy: 0.5312
# Batch no: 058, Loss on trainig: 1.4819, Accuracy: 0.5781
# Batch no: 059, Loss on trainig: 1.6979, Accuracy: 0.4844
# Batch no: 060, Loss on trainig: 1.2000, Accuracy: 0.6562
# Batch no: 061, Loss on trainig: 1.3858, Accuracy: 0.6250
# Batch no: 062, Loss on trainig: 1.5200, Accuracy: 0.6406
# Batch no: 063, Loss on trainig: 1.2691, Accuracy: 0.6250
# Batch no: 064, Loss on trainig: 1.0979, Accuracy: 0.6250
# Batch no: 065, Loss on trainig: 1.4937, Accuracy: 0.5781
# Batch no: 066, Loss on trainig: 1.6602, Accuracy: 0.5156
# Batch no: 067, Loss on trainig: 1.4096, Accuracy: 0.5781
# Batch no: 068, Loss on trainig: 1.6951, Accuracy: 0.5625
# Batch no: 069, Loss on trainig: 1.4357, Accuracy: 0.6250
# Batch no: 070, Loss on trainig: 1.6491, Accuracy: 0.5469
# Batch no: 071, Loss on trainig: 1.3596, Accuracy: 0.5781
# Batch no: 072, Loss on trainig: 1.3674, Accuracy: 0.6250
# Batch no: 073, Loss on trainig: 1.4981, Accuracy: 0.5781
# Batch no: 074, Loss on trainig: 1.6070, Accuracy: 0.5625
# Batch no: 075, Loss on trainig: 1.2054, Accuracy: 0.6562
# Batch no: 076, Loss on trainig: 1.4638, Accuracy: 0.5781
# Batch no: 077, Loss on trainig: 1.1201, Accuracy: 0.6562
# Batch no: 078, Loss on trainig: 1.2121, Accuracy: 0.6719
# Batch no: 079, Loss on trainig: 1.4936, Accuracy: 0.5781
# Batch no: 080, Loss on trainig: 1.2999, Accuracy: 0.5625
# Batch no: 081, Loss on trainig: 1.3127, Accuracy: 0.5625
# Batch no: 082, Loss on trainig: 1.1478, Accuracy: 0.7344
# Batch no: 083, Loss on trainig: 1.4318, Accuracy: 0.5781
# Batch no: 084, Loss on trainig: 1.4171, Accuracy: 0.5469
# Batch no: 085, Loss on trainig: 1.1080, Accuracy: 0.6562
# Batch no: 086, Loss on trainig: 1.2812, Accuracy: 0.6562
# Batch no: 087, Loss on trainig: 1.3978, Accuracy: 0.5781
# Batch no: 088, Loss on trainig: 1.5212, Accuracy: 0.5625
# Batch no: 089, Loss on trainig: 1.4948, Accuracy: 0.5625
# Batch no: 090, Loss on trainig: 1.6074, Accuracy: 0.5156
# Batch no: 091, Loss on trainig: 1.2433, Accuracy: 0.6406
# Batch no: 092, Loss on trainig: 1.2458, Accuracy: 0.5781
# Batch no: 093, Loss on trainig: 1.5782, Accuracy: 0.6406
# Batch no: 094, Loss on trainig: 1.6685, Accuracy: 0.5156
# Batch no: 095, Loss on trainig: 1.7584, Accuracy: 0.5469
# Batch no: 096, Loss on trainig: 1.2540, Accuracy: 0.6406
# Batch no: 097, Loss on trainig: 1.4819, Accuracy: 0.5781
# Batch no: 098, Loss on trainig: 1.1417, Accuracy: 0.6562
# Batch no: 099, Loss on trainig: 1.3278, Accuracy: 0.6562
# Batch no: 100, Loss on trainig: 1.4458, Accuracy: 0.6250
# Batch no: 101, Loss on trainig: 1.0162, Accuracy: 0.7188
# Batch no: 102, Loss on trainig: 1.5834, Accuracy: 0.4583
# Epoch: 18/18
# Batch no: 000, Loss on trainig: 1.3249, Accuracy: 0.6250
# Batch no: 001, Loss on trainig: 1.3239, Accuracy: 0.6719
# Batch no: 002, Loss on trainig: 1.1873, Accuracy: 0.6250
# Batch no: 003, Loss on trainig: 1.4267, Accuracy: 0.6250
# Batch no: 004, Loss on trainig: 1.4858, Accuracy: 0.6094
# Batch no: 005, Loss on trainig: 1.1729, Accuracy: 0.6875
# Batch no: 006, Loss on trainig: 1.2581, Accuracy: 0.6094
# Batch no: 007, Loss on trainig: 1.5273, Accuracy: 0.6250
# Batch no: 008, Loss on trainig: 1.7060, Accuracy: 0.5625
# Batch no: 009, Loss on trainig: 1.3505, Accuracy: 0.5625
# Batch no: 010, Loss on trainig: 1.2900, Accuracy: 0.6094
# Batch no: 011, Loss on trainig: 1.1973, Accuracy: 0.6875
# Batch no: 012, Loss on trainig: 1.5945, Accuracy: 0.5156
# Batch no: 013, Loss on trainig: 1.3637, Accuracy: 0.5781
# Batch no: 014, Loss on trainig: 1.1434, Accuracy: 0.6875
# Batch no: 015, Loss on trainig: 1.5322, Accuracy: 0.5625
# Batch no: 016, Loss on trainig: 0.9871, Accuracy: 0.7500
# Batch no: 017, Loss on trainig: 1.0841, Accuracy: 0.6875
# Batch no: 018, Loss on trainig: 1.2158, Accuracy: 0.6875
# Batch no: 019, Loss on trainig: 1.0679, Accuracy: 0.7656
# Batch no: 020, Loss on trainig: 1.5204, Accuracy: 0.5312
# Batch no: 021, Loss on trainig: 0.9910, Accuracy: 0.6875
# Batch no: 022, Loss on trainig: 1.4566, Accuracy: 0.6094
# Batch no: 023, Loss on trainig: 1.5926, Accuracy: 0.5625
# Batch no: 024, Loss on trainig: 0.9809, Accuracy: 0.7188
# Batch no: 025, Loss on trainig: 0.9439, Accuracy: 0.6875
# Batch no: 026, Loss on trainig: 1.2841, Accuracy: 0.5938
# Batch no: 027, Loss on trainig: 1.6054, Accuracy: 0.5312
# Batch no: 028, Loss on trainig: 1.5953, Accuracy: 0.5938
# Batch no: 029, Loss on trainig: 1.3592, Accuracy: 0.6250
# Batch no: 030, Loss on trainig: 1.2824, Accuracy: 0.6250
# Batch no: 031, Loss on trainig: 1.2370, Accuracy: 0.6094
# Batch no: 032, Loss on trainig: 1.5837, Accuracy: 0.5469
# Batch no: 033, Loss on trainig: 1.5067, Accuracy: 0.5938
# Batch no: 034, Loss on trainig: 1.2580, Accuracy: 0.6719
# Batch no: 035, Loss on trainig: 1.1402, Accuracy: 0.6719
# Batch no: 036, Loss on trainig: 1.0686, Accuracy: 0.6875
# Batch no: 037, Loss on trainig: 1.8897, Accuracy: 0.5625
# Batch no: 038, Loss on trainig: 1.7749, Accuracy: 0.5781
# Batch no: 039, Loss on trainig: 1.5047, Accuracy: 0.5625
# Batch no: 040, Loss on trainig: 1.4348, Accuracy: 0.6094
# Batch no: 041, Loss on trainig: 1.4540, Accuracy: 0.5625
# Batch no: 042, Loss on trainig: 1.0650, Accuracy: 0.6562
# Batch no: 043, Loss on trainig: 1.2596, Accuracy: 0.6562
# Batch no: 044, Loss on trainig: 1.2389, Accuracy: 0.6406
# Batch no: 045, Loss on trainig: 1.6370, Accuracy: 0.5312
# Batch no: 046, Loss on trainig: 1.3538, Accuracy: 0.5469
# Batch no: 047, Loss on trainig: 1.5410, Accuracy: 0.5781
# Batch no: 048, Loss on trainig: 1.1929, Accuracy: 0.6719
# Batch no: 049, Loss on trainig: 1.3621, Accuracy: 0.6406
# Batch no: 050, Loss on trainig: 1.4910, Accuracy: 0.5781
# Batch no: 051, Loss on trainig: 1.4146, Accuracy: 0.5469
# Batch no: 052, Loss on trainig: 1.4330, Accuracy: 0.6094
# Batch no: 053, Loss on trainig: 1.4114, Accuracy: 0.6094
# Batch no: 054, Loss on trainig: 1.0973, Accuracy: 0.7344
# Batch no: 055, Loss on trainig: 1.4146, Accuracy: 0.6250
# Batch no: 056, Loss on trainig: 1.2476, Accuracy: 0.6875
# Batch no: 057, Loss on trainig: 1.0940, Accuracy: 0.6875
# Batch no: 058, Loss on trainig: 1.5367, Accuracy: 0.5469
# Batch no: 059, Loss on trainig: 1.4635, Accuracy: 0.6719
# Batch no: 060, Loss on trainig: 1.3963, Accuracy: 0.6094
# Batch no: 061, Loss on trainig: 1.2674, Accuracy: 0.5781
# Batch no: 062, Loss on trainig: 1.3597, Accuracy: 0.6562
# Batch no: 063, Loss on trainig: 1.5420, Accuracy: 0.6562
# Batch no: 064, Loss on trainig: 1.1622, Accuracy: 0.6562
# Batch no: 065, Loss on trainig: 1.1640, Accuracy: 0.6562
# Batch no: 066, Loss on trainig: 1.2884, Accuracy: 0.5938
# Batch no: 067, Loss on trainig: 1.4620, Accuracy: 0.6094
# Batch no: 068, Loss on trainig: 1.3026, Accuracy: 0.5469
# Batch no: 069, Loss on trainig: 1.3928, Accuracy: 0.6250
# Batch no: 070, Loss on trainig: 1.6798, Accuracy: 0.5938
# Batch no: 071, Loss on trainig: 1.5836, Accuracy: 0.5156
# Batch no: 072, Loss on trainig: 1.0388, Accuracy: 0.6562
# Batch no: 073, Loss on trainig: 1.4079, Accuracy: 0.5469
# Batch no: 074, Loss on trainig: 1.3744, Accuracy: 0.5938
# Batch no: 075, Loss on trainig: 1.0215, Accuracy: 0.6562
# Batch no: 076, Loss on trainig: 1.1044, Accuracy: 0.6562
# Batch no: 077, Loss on trainig: 1.2243, Accuracy: 0.6406
# Batch no: 078, Loss on trainig: 1.3144, Accuracy: 0.6875
# Batch no: 079, Loss on trainig: 1.5378, Accuracy: 0.5312
# Batch no: 080, Loss on trainig: 1.3787, Accuracy: 0.6406
# Batch no: 081, Loss on trainig: 1.1583, Accuracy: 0.7656
# Batch no: 082, Loss on trainig: 1.1842, Accuracy: 0.6562
# Batch no: 083, Loss on trainig: 1.2681, Accuracy: 0.6562
# Batch no: 084, Loss on trainig: 1.1362, Accuracy: 0.6406
# Batch no: 085, Loss on trainig: 1.4604, Accuracy: 0.5625
# Batch no: 086, Loss on trainig: 1.4242, Accuracy: 0.5312
# Batch no: 087, Loss on trainig: 1.4244, Accuracy: 0.5781
# Batch no: 088, Loss on trainig: 1.5435, Accuracy: 0.5469
# Batch no: 089, Loss on trainig: 1.3545, Accuracy: 0.6094
# Batch no: 090, Loss on trainig: 0.9236, Accuracy: 0.7188
# Batch no: 091, Loss on trainig: 1.3084, Accuracy: 0.5938
# Batch no: 092, Loss on trainig: 1.0537, Accuracy: 0.7188
# Batch no: 093, Loss on trainig: 1.3307, Accuracy: 0.6562
# Batch no: 094, Loss on trainig: 1.0594, Accuracy: 0.6250
# Batch no: 095, Loss on trainig: 1.4618, Accuracy: 0.5469
# Batch no: 096, Loss on trainig: 1.7743, Accuracy: 0.5469
# Batch no: 097, Loss on trainig: 1.5289, Accuracy: 0.5625
# Batch no: 098, Loss on trainig: 1.2394, Accuracy: 0.6406
# Batch no: 099, Loss on trainig: 1.4131, Accuracy: 0.5938
# Batch no: 100, Loss on trainig: 1.5247, Accuracy: 0.6406
# Batch no: 101, Loss on trainig: 1.6516, Accuracy: 0.5156
# Batch no: 102, Loss on trainig: 1.4036, Accuracy: 0.5833

# %%
# TODO: Do validation on the test set
#Maintaining a separate validation set is important, 
#so that we can stop the training at the right point and prevent overfitting. 
#Validation is carried out in each epoch immediately after the training loop.
#Since we do not need any gradient computation in the validation process, it is done with torch.no_grad().
#For each validation batch, the inputs and labels are transferred to the GPU ( if cuda is available, else cpu).
#The inputs go through the forwards pass, 
#followed by the loss and accuracy computations for the batch and at the end of the loop, for the whole epoch.

# Validation - No gradient tracking needed
with torch.no_grad():
 
    # Set to evaluation mode
    model.eval()


    # Validation loop
    for j, (inputs, labels) in enumerate(validation_loader):
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')
 
        # Forward pass - compute outputs on input data using the model
        outputs = model(inputs)
 
        # Compute loss
        loss = criterion(outputs, labels)
 
        # Compute the total loss for the batch and add it to valid_loss
        valid_loss += loss.item() * inputs.size(0)
 
        # Calculate validation accuracy
        ret, predictions = torch.max(outputs.data, 1)
        correct_counts = predictions.eq(labels.data.view_as(predictions))
 
        # Convert correct_counts to float and then compute the mean
        acc = torch.mean(correct_counts.type(torch.FloatTensor))
 
        # Compute total accuracy in the whole batch and add to valid_acc
        valid_acc += acc.item() * inputs.size(0)
 
        print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
# Out:
# Validation Batch number: 000, Validation: Loss: 0.5733, Accuracy: 0.8281
# Validation Batch number: 001, Validation: Loss: 0.3187, Accuracy: 0.9219
# Validation Batch number: 002, Validation: Loss: 0.7022, Accuracy: 0.7656
# Validation Batch number: 003, Validation: Loss: 0.5069, Accuracy: 0.8125
# Validation Batch number: 004, Validation: Loss: 0.7962, Accuracy: 0.7656
# Validation Batch number: 005, Validation: Loss: 0.3854, Accuracy: 0.8594
# Validation Batch number: 006, Validation: Loss: 0.4125, Accuracy: 0.8750
# Validation Batch number: 007, Validation: Loss: 0.9151, Accuracy: 0.7969
# Validation Batch number: 008, Validation: Loss: 0.4602, Accuracy: 0.8281
# Validation Batch number: 009, Validation: Loss: 0.6711, Accuracy: 0.7656
# Validation Batch number: 010, Validation: Loss: 0.5298, Accuracy: 0.8750
# Validation Batch number: 011, Validation: Loss: 0.6301, Accuracy: 0.8125
# Validation Batch number: 012, Validation: Loss: 0.4086, Accuracy: 0.8800

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# Do validation on the test set
correct,total = 0,0
with torch.no_grad():
    model.eval()
    for data in train_loader:
        images, labels = data
        images, labels = images.to('cuda'), labels.to('cuda')
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy on test images is: %d%%' % (100 * correct / total))
# Out:
# Accuracy on test images is: 80%

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
#The class ImageFolder has an attribute class_to_idx which is a dictionary mapping the name of the class to the index (label).
#So, you can access the classes with data.classes and for each class get the label with data.class_to_idx.

#torch.save: Saves a serialized object to disk. This function uses Python’s pickle utility for serialization.
#Models, tensors, and dictionaries of all kinds of objects can be saved using this function.
#torch.save(model, PATH)
#reference:https://pytorch.org/tutorials/beginner/saving_loading_models.html

model.class_to_idx = image_datasets['train'].class_to_idx
torch.save({'structure' :'alexnet',
            'hidden_layer1':120,
             'droupout':0.5,
             'epochs':12,
             'state_dict':model.state_dict(),
             'class_to_idx':model.class_to_idx,
             'optimizer_dict':optimizer.state_dict()},
             'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model

#torch.load: Uses pickle’s unpickling facilities to deserialize pickled object files to memory. 
#This function also facilitates the device to load the data into
#When you call torch.load() on a file which contains GPU tensors, 
#those tensors will be loaded to GPU by default. You can call torch.load(.., map_location='cpu')
# and then load_state_dict() to avoid GPU RAM surge when loading a model checkpoint.
##reference:https://pytorch.org/tutorials/beginner/saving_loading_models.html
def loading_the_checkpoint(path='checkpoint.pth'):
    #load the saved file
    checkpoint = torch.load('checkpoint.pth')
    #download pretrained model
    model=models.vgg16(pretrained=True)
    #to freeze parameters
    for param in model.parameters():
        param.requires_grad = False
    #load from checkpoint
    model.class_to_idx = checkpoint['class_to_idx']
    model.load_state_dict(checkpoint['state_dict'])
    return model

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
# TODO: Process a PIL image for use in a PyTorch model
#Image.thumbnail(size, resample=3)
#https://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail
# Crop the center of the image-->.crop((left, top, right, bottom))
#a.transpose().shape = (i[n-1], i[n-2], ... i[1], i[0])
#Refrence on processing the image-->https://stackoverflow.com/questions/55678459/resize-image-in-python
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''

    img = PIL.Image.open(image)

    # Get original dimensions
    original_width, original_height = img.size

    # Find shorter size and create settings to crop shortest side to 256
    if original_width < original_height:
        size=[256, 256**600]
    else: 
        size=[256**600, 256]
        
    img.thumbnail(size)
   

    center = original_width/4, original_height/4
    left, top, right, bottom = center[0]-(244/2), center[1]-(244/2), center[0]+(244/2), center[1]+(244/2)
    img = img.crop((left, top, right, bottom))

    numpy_img = np.array(img)/255 

    # Normalize each color channel
    mean = [0.485, 0.456, 0.406]
    std = [0.229, 0.224, 0.225]
    numpy_img = (numpy_img-mean)/std
        
    # Set the color to the first channel
    numpy_img = numpy_img.transpose(2, 0, 1)
    
    return numpy_img

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    #img for tensor
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0))   
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

imshow(process_image("/kaggle/working/flowers/test/9/image_06413.jpg"))
imshow(process_image("/kaggle/working/flowers/test/37/image_03734.jpg"))
imshow(process_image("/kaggle/working/flowers/test/10/image_07104.jpg"))
# Out:
# <Axes: >

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, top_k=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    
    image_path: string. Path to image, directly to image and not to folder.
    model: pytorch neural network.
    top_k: integer. The top K classes to be calculated
    
    returns top_probabilities(k), top_labels
    '''
    
    # No need for GPU on this part (just causes problems)
    model.to("cpu")
    
    # Set model to evaluate
    model.eval();

    # Convert image from numpy to torch
    torch_image = torch.from_numpy(np.expand_dims(process_image(image_path), 
                                                  axis=0)).type(torch.FloatTensor).to("cpu")

    # Find probabilities (results) by passing through the function (note the log softmax means that its on a log scale)
    log_probs = model.forward(torch_image)

    # Convert to linear scale
    linear_probs = torch.exp(log_probs)

    # Find the top 5 results
    top_probs, top_labels = linear_probs.topk(top_k)
    
    # Detatch all of the details
    top_probs = np.array(top_probs.detach())[0] # This is not the correct way to do it but the correct way isnt working thanks to cpu/gpu issues so I don't care.
    top_labels = np.array(top_labels.detach())[0]
    
    # Convert to classes
    idx_to_class = {val: key for key, val in    
                                      model.class_to_idx.items()}
    top_labels = [idx_to_class[lab] for lab in top_labels]
    top_flowers = [cat_to_name[lab] for lab in top_labels]
    
    return top_probs, top_labels, top_flowers

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
# Define image path
image_path = "flowers/test/37/image_03734.jpg"

# Set up plot
plt.figure(figsize = (6,10))
ax = plt.subplot(2,1,1)

# Set up title
flower_num = image_path.split('/')[2]
title_ = cat_to_name[flower_num]

# Plot flower
img = process_image(image_path)
imshow(img, ax, title = title_);

# Make prediction
probs, labs, flowers = predict(image_path, model) 

# Plot bar chart
plt.subplot(2,1,2)
sns.barplot(x=probs, y=flowers, color=sns.color_palette()[0]);
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %% [markdown]
# ## Reminder for Workspace users
# If your network becomes very large when saved as a checkpoint, there might be issues with saving backups in your workspace. You should reduce the size of your hidden layers and train again.
#
# We strongly encourage you to delete these large interim files and directories before navigating to another page or closing the browser tab.

# %%
image_path = "flowers/test/9/image_06413.jpg"
plt.figure(figsize = (6,10))
ax = plt.subplot(2,1,1)
flower_num = image_path.split('/')[2]
title_ = cat_to_name[flower_num]
img = process_image(image_path)
imshow(img, ax, title = title_);
probs, labs, flowers = predict(image_path, model) 
plt.subplot(2,1,2)
sns.barplot(x=probs, y=flowers, color=sns.color_palette()[0]);
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %%
image_path = "flowers/test/10/image_07104.jpg"
plt.figure(figsize = (6,10))
ax = plt.subplot(2,1,1)
flower_num = image_path.split('/')[2]
title_ = cat_to_name[flower_num]
img = process_image(image_path)
imshow(img, ax, title = title_);
probs, labs, flowers = predict(image_path, model) 
plt.subplot(2,1,2)
sns.barplot(x=probs, y=flowers, color=sns.color_palette()[0]);
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
